# %%
import tensorflow as tf
from tensorflow import keras   #keras in a deep learning lib based on python
import numpy as np
import matplotlib.pyplot as plt

# %%
data = keras.datasets.imdb  #IMDB Movie reviews sentiment classification

# %%
(train_data, train_labels),(test_data, test_labels) = data.load_data(num_words=10000)

# %%
print(train_data[0])  # words from dictionary
# Out:
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]

# %%
word_index = data.get_word_index()

word_index = {k:(v+3) for k,v in word_index.items()}  #add 3 values in the dict
word_index["<PAD>"]=0  #to make all comments the same length, we should add paddings
word_index["<START>"]=1
word_index["<UNK>"]=2
word_index["<UNUSED>"]=3

# %%
reverse_word_index = dict([(value,key) for (key,value) in word_index.items()])  #translate back to natual language

# %%
print(len(test_data[0]),len(test_data[1]))
# Out:
# 68 260

# %%
#fill comments which do not contains enough words(<250>) with <PAD>
train_data = keras.preprocessing.sequence.pad_sequences(train_data, value=word_index["<PAD>"], padding="post", maxlen=250)
test_data = keras.preprocessing.sequence.pad_sequences(test_data, value=word_index["<PAD>"], padding="post", maxlen=250)

# %%
def decode_review(text):
    return " ".join([reverse_word_index.get(i,"?") for i in text])

# %%
print(len(test_data[0]),len(test_data[1]))
# Out:
# 250 250

# %%
model = keras.Sequential()          
#input is a comment, eg: It is a great movie.  ==   [23,124,5432,213]
model.add(keras.layers.Embedding(10000,16)) 
#embedding layer
#for each word we use a 10000-D vector to represent it (one-hot)
#for the content of each word(a 10000-D vector), we use 16 co-efficents to represent it
#let the "angle" of 2 similar meaning words be smaller
#let the "angle" of 2 disimilar meaning words be bigger
model.add(keras.layers.GlobalAveragePooling1D())   #avg pooling layer, recuce scale
model.add(keras.layers.Dense(16,activation="relu"))  #classfication, use 16 neurons to pick up pattern of certain words
model.add(keras.layers.Dense(1,activation="sigmoid")) #classfication, output layer: 0 or 1 (comment is positive or negative)

# %%
model.summary()
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 16)          160000
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 16)                0
# _________________________________________________________________
# dense (Dense)                (None, 16)                272
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 160,289
# Trainable params: 160,289
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_validation = train_data[:10000]
x_train = train_data[10000:]
y_validation = train_labels[:10000]
y_train = train_labels[10000:]

# %%
fitModel = model.fit(x_train,y_train,epochs=40,batch_size=512, validation_data=(x_validation,y_validation), verbose=1)
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/40
# 15000/15000 [==============================] - 2s 123us/sample - loss: 0.6918 - accuracy: 0.5509 - val_loss: 0.6899 - val_accuracy: 0.7018
# Epoch 2/40
# 15000/15000 [==============================] - 1s 43us/sample - loss: 0.6861 - accuracy: 0.7226 - val_loss: 0.6819 - val_accuracy: 0.7324
# Epoch 3/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.6737 - accuracy: 0.7559 - val_loss: 0.6667 - val_accuracy: 0.7485
# Epoch 4/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.6523 - accuracy: 0.7667 - val_loss: 0.6423 - val_accuracy: 0.7628
# Epoch 5/40
# 15000/15000 [==============================] - 1s 44us/sample - loss: 0.6206 - accuracy: 0.7888 - val_loss: 0.6085 - val_accuracy: 0.7798
# Epoch 6/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.5800 - accuracy: 0.8056 - val_loss: 0.5687 - val_accuracy: 0.7983
# Epoch 7/40
# 15000/15000 [==============================] - 1s 43us/sample - loss: 0.5341 - accuracy: 0.8235 - val_loss: 0.5261 - val_accuracy: 0.8130
# Epoch 8/40
# 15000/15000 [==============================] - 1s 43us/sample - loss: 0.4871 - accuracy: 0.8418 - val_loss: 0.4847 - val_accuracy: 0.8281
# Epoch 9/40
# 15000/15000 [==============================] - 1s 43us/sample - loss: 0.4425 - accuracy: 0.8571 - val_loss: 0.4466 - val_accuracy: 0.8399
# Epoch 10/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.4020 - accuracy: 0.8692 - val_loss: 0.4139 - val_accuracy: 0.8477
# Epoch 11/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.3671 - accuracy: 0.8819 - val_loss: 0.3873 - val_accuracy: 0.8556
# Epoch 12/40
# 15000/15000 [==============================] - 1s 47us/sample - loss: 0.3381 - accuracy: 0.8883 - val_loss: 0.3667 - val_accuracy: 0.8621
# Epoch 13/40
# 15000/15000 [==============================] - 1s 45us/sample - loss: 0.3140 - accuracy: 0.8950 - val_loss: 0.3498 - val_accuracy: 0.8661
# Epoch 14/40
# 15000/15000 [==============================] - 1s 43us/sample - loss: 0.2933 - accuracy: 0.9001 - val_loss: 0.3370 - val_accuracy: 0.8683
# Epoch 15/40
# 15000/15000 [==============================] - 1s 45us/sample - loss: 0.2756 - accuracy: 0.9045 - val_loss: 0.3264 - val_accuracy: 0.8726
# Epoch 16/40
# 15000/15000 [==============================] - 1s 43us/sample - loss: 0.2602 - accuracy: 0.9091 - val_loss: 0.3197 - val_accuracy: 0.8712
# Epoch 17/40
# 15000/15000 [==============================] - 1s 43us/sample - loss: 0.2467 - accuracy: 0.9144 - val_loss: 0.3097 - val_accuracy: 0.8777
# Epoch 18/40
# 15000/15000 [==============================] - 1s 45us/sample - loss: 0.2334 - accuracy: 0.9194 - val_loss: 0.3040 - val_accuracy: 0.8799
# Epoch 19/40
# 15000/15000 [==============================] - 1s 45us/sample - loss: 0.2223 - accuracy: 0.9226 - val_loss: 0.2992 - val_accuracy: 0.8814
# Epoch 20/40
# 15000/15000 [==============================] - 1s 45us/sample - loss: 0.2115 - accuracy: 0.9263 - val_loss: 0.2954 - val_accuracy: 0.8823
# Epoch 21/40
# 15000/15000 [==============================] - 1s 43us/sample - loss: 0.2020 - accuracy: 0.9304 - val_loss: 0.2921 - val_accuracy: 0.8833
# Epoch 22/40
# 15000/15000 [==============================] - 1s 44us/sample - loss: 0.1925 - accuracy: 0.9344 - val_loss: 0.2903 - val_accuracy: 0.8837
# Epoch 23/40
# 15000/15000 [==============================] - 1s 46us/sample - loss: 0.1843 - accuracy: 0.9382 - val_loss: 0.2883 - val_accuracy: 0.8836
# Epoch 24/40
# 15000/15000 [==============================] - 1s 45us/sample - loss: 0.1761 - accuracy: 0.9425 - val_loss: 0.2868 - val_accuracy: 0.8852
# Epoch 25/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.1693 - accuracy: 0.9453 - val_loss: 0.2862 - val_accuracy: 0.8848
# Epoch 26/40
# 15000/15000 [==============================] - 1s 45us/sample - loss: 0.1617 - accuracy: 0.9485 - val_loss: 0.2856 - val_accuracy: 0.8858
# Epoch 27/40
# 15000/15000 [==============================] - 1s 44us/sample - loss: 0.1552 - accuracy: 0.9514 - val_loss: 0.2856 - val_accuracy: 0.8852
# Epoch 28/40
# 15000/15000 [==============================] - 1s 43us/sample - loss: 0.1489 - accuracy: 0.9535 - val_loss: 0.2867 - val_accuracy: 0.8854
# Epoch 29/40
# 15000/15000 [==============================] - 1s 43us/sample - loss: 0.1428 - accuracy: 0.9573 - val_loss: 0.2875 - val_accuracy: 0.8855
# Epoch 30/40
# 15000/15000 [==============================] - 1s 43us/sample - loss: 0.1374 - accuracy: 0.9585 - val_loss: 0.2880 - val_accuracy: 0.8862
# Epoch 31/40
# 15000/15000 [==============================] - 1s 42us/sample - loss: 0.1324 - accuracy: 0.9607 - val_loss: 0.2910 - val_accuracy: 0.8835
# Epoch 32/40
# 15000/15000 [==============================] - 1s 44us/sample - loss: 0.1273 - accuracy: 0.9624 - val_loss: 0.2903 - val_accuracy: 0.8860
# Epoch 33/40
# 15000/15000 [==============================] - 1s 44us/sample - loss: 0.1221 - accuracy: 0.9647 - val_loss: 0.2927 - val_accuracy: 0.8859
# Epoch 34/40
# 15000/15000 [==============================] - 1s 45us/sample - loss: 0.1174 - accuracy: 0.9665 - val_loss: 0.2943 - val_accuracy: 0.8863
# Epoch 35/40
# 15000/15000 [==============================] - 1s 43us/sample - loss: 0.1133 - accuracy: 0.9681 - val_loss: 0.2988 - val_accuracy: 0.8831
# Epoch 36/40
# 15000/15000 [==============================] - 1s 46us/sample - loss: 0.1088 - accuracy: 0.9695 - val_loss: 0.2998 - val_accuracy: 0.8857
# Epoch 37/40
# 15000/15000 [==============================] - 1s 47us/sample - loss: 0.1043 - accuracy: 0.9717 - val_loss: 0.3021 - val_accuracy: 0.8852
# Epoch 38/40
# 15000/15000 [==============================] - 1s 47us/sample - loss: 0.1004 - accuracy: 0.9728 - val_loss: 0.3052 - val_accuracy: 0.8845
# Epoch 39/40
# 15000/15000 [==============================] - 1s 44us/sample - loss: 0.0966 - accuracy: 0.9748 - val_loss: 0.3072 - val_accuracy: 0.8824
# Epoch 40/40
# 15000/15000 [==============================] - 1s 44us/sample - loss: 0.0930 - accuracy: 0.9764 - val_loss: 0.3105 - val_accuracy: 0.8825

# %%
results = model.evaluate(test_data,test_labels)
# Out:
# 25000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print(results)  #loss,accuracy
# Out:
# [0.3328003268909454, 0.87048]

# %%
#make a prediction
test_review = test_data[0]
predict = model.predict([test_review])
print("Review: ")
print(decode_review(test_review))
print("Prediction: "+str(predict[0]))
print("Actual: "+str(test_labels[0]))
print(results)  #  0:bad    1:good
# Out:
# Review:
# <START> please give this one a miss br br <UNK> <UNK> and the rest of the cast rendered terrible performances the show is flat flat flat br br i don't know how michael madison could have allowed this one on his plate he almost seemed to know this wasn't going to work out and his performance was quite <UNK> so all you madison fans give this a miss <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Prediction: [0.]
# Actual: 0
# [0.3328003268909454, 0.87048]

# %%
#saving the model
model.save("model.h5")

# %%
#loading model
modelFY = keras.models.load_model("model.h5")
