# %%
import time
import psutil
import matplotlib.pyplot as plt
# %matplotlib notebook
plt.rcParams['animation.html']='jshtml'

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
psutil.cpu_percent()
# Out:
# 50.8

# %%
i = 0
x,y=[],[]
while True:
    x.append(i)
    y.append(psutil.cpu_percent())
    ax.plot(x,y,color='b')
    fig.canvas.draw()
    ax.set_xlim(left=max(0.1,i-50),right=i+50)
    time.sleep(0.1)
    i+=1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-b9d86b4f3df7> in <module>
#       7     fig.canvas.draw()
#       8     ax.set_xlim(left=max(0.1,i-50),right=i+50)
# ----> 9     time.sleep(0.1)
#      10     i+=1
#
# KeyboardInterrupt:

# %%
plt.close()
