# %%
import tensorflow as tf
from sklearn.metrics import accuracy_score
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPool2D, Dropout
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
print("GPU Available: ", tf.test.is_gpu_available()) 
print(tf.__version__)
# Out:
# GPU Available:  True
# 2.0.0

# %%
## Between the conv and FC layer, there is a Flatten layer.
## Flatening transforms a 2D matrix of features into a vector that can be fed into FC NN classifier

# %% [markdown]
# ## Data preparation

# %%
from tensorflow.keras.datasets import cifar10

# %%
(X_train,y_train),(X_test,y_test)=cifar10.load_data()

# %%
classes_name = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog' ,'frog', 'horse','ship','truck']

# %%
X_train.max()
# Out:
# 255

# %%
X_train=X_train/255.0
X_test=X_test/255.0

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
X_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
plt.imshow(X_test[0])

# %%
y_test
# Out:
# array([[3],
#        [8],
#        [8],
#        ...,
#        [5],
#        [1],
#        [7]], dtype=uint8)

# %% [markdown]
# ## CNN model

# %%
model = Sequential()
model.add(Conv2D(filters=32,kernel_size=(3,3),padding='same',activation='relu',input_shape=[32,32,3]))
model.add(Conv2D(filters=32,kernel_size=(3,3),padding='same',activation='relu'))
model.add(MaxPool2D(pool_size=(2,2),strides=2,padding='valid'))
# about padding option: full, valid, same, check: https://www.cnblogs.com/sddai/p/10512784.html
model.add(Dropout(0.5))
## Between the conv and FC layer, there is a Flatten layer.
## Flatening transforms a 2D matrix of features into a vector that can be fed into FC NN classifier
model.add(Flatten())
model.add(Dense(units=128,activation='relu'))
model.add(Dense(units=10,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1048704
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 1,060,138
# Trainable params: 1,060,138
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['sparse_categorical_accuracy'])

# %%
history = model.fit(X_train,y_train,batch_size=10,epochs=10,verbose=1,validation_data=(X_test,y_test))
#verbose:日志显示，0为不在标准输出流输出日志信息，1为输出进度条记录，2为每个epoch输出一行记录
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 17s 331us/sample - loss: 1.3774 - sparse_categorical_accuracy: 0.5058 - val_loss: 1.1396 - val_sparse_categorical_accuracy: 0.5937
# Epoch 2/10
# 50000/50000 [==============================] - 14s 285us/sample - loss: 1.0728 - sparse_categorical_accuracy: 0.6225 - val_loss: 0.9913 - val_sparse_categorical_accuracy: 0.6443
# Epoch 3/10
# 50000/50000 [==============================] - 14s 284us/sample - loss: 0.9429 - sparse_categorical_accuracy: 0.6679 - val_loss: 0.9533 - val_sparse_categorical_accuracy: 0.6619
# Epoch 4/10
# 50000/50000 [==============================] - 15s 294us/sample - loss: 0.8489 - sparse_categorical_accuracy: 0.6994 - val_loss: 0.8994 - val_sparse_categorical_accuracy: 0.6819
# Epoch 5/10
# 50000/50000 [==============================] - 14s 286us/sample - loss: 0.7733 - sparse_categorical_accuracy: 0.7266 - val_loss: 0.9140 - val_sparse_categorical_accuracy: 0.6874
# Epoch 6/10
# 50000/50000 [==============================] - 15s 290us/sample - loss: 0.7185 - sparse_categorical_accuracy: 0.7441 - val_loss: 0.8857 - val_sparse_categorical_accuracy: 0.6917
# Epoch 7/10
# 50000/50000 [==============================] - 14s 286us/sample - loss: 0.6640 - sparse_categorical_accuracy: 0.7650 - val_loss: 0.8882 - val_sparse_categorical_accuracy: 0.7012
# Epoch 8/10
# 50000/50000 [==============================] - 14s 287us/sample - loss: 0.6202 - sparse_categorical_accuracy: 0.7797 - val_loss: 0.9289 - val_sparse_categorical_accuracy: 0.6884
# Epoch 9/10
# 50000/50000 [==============================] - 15s 304us/sample - loss: 0.5815 - sparse_categorical_accuracy: 0.7916 - val_loss: 0.9267 - val_sparse_categorical_accuracy: 0.7001
# Epoch 10/10
# 50000/50000 [==============================] - 15s 298us/sample - loss: 0.5489 - sparse_categorical_accuracy: 0.8046 - val_loss: 0.9428 - val_sparse_categorical_accuracy: 0.6979

# %%
epoch_range=range(1,11)
plt.plot(epoch_range,history.history['sparse_categorical_accuracy'])
plt.plot(epoch_range,history.history['val_sparse_categorical_accuracy'])

plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train'],loc='upper left')
plt.show()

plt.plot(epoch_range,history.history['loss'])
plt.plot(epoch_range,history.history['val_loss'])

plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Val'],loc='upper left')
plt.show()

#  train acc > val acc means over fitting, stop training
#  stop training at around epoch 6

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %%
y_pred = model.predict_classes(X_test)

# %%
mat = confusion_matrix(y_test,y_pred)
plot_confusion_matrix(conf_mat=mat,figsize=(8,8), class_names=classes_name,show_normed=True)
# Out:
# (<Figure size 576x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x21ad4c3cf48>)
