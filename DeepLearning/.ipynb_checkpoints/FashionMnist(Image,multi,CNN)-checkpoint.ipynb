# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Dropout, Flatten, BatchNormalization, MaxPool2D, SpatialDropout2D
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Import data

# %%
data = keras.datasets.fashion_mnist  
(X_train, y_train),(X_test, y_test) = data.load_data()
X_train.shape,y_train.shape,X_test.shape,y_test.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
class_names = ['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']

# %% [markdown]
# ## Data exploration

# %%
plt.figure()
plt.imshow(X_train[0])
plt.colorbar()

# %% [markdown]
# ## Data preprocessing

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train,y_train,test_size=0.2,random_state=0)
X_train.shape,y_train.shape,X_val.shape,y_val.shape,X_test.shape,y_test.shape
# Out:
# ((48000, 28, 28),
#  (48000,),
#  (12000, 28, 28),
#  (12000,),
#  (10000, 28, 28),
#  (10000,))

# %%
X_train=X_train/255.0
X_test=X_test/255.0
X_val=X_val/255.0

# %%
X_train=X_train.reshape(48000, 28, 28,1)
X_val=X_val.reshape(12000, 28, 28,1)
X_test=X_test.reshape(10000, 28, 28,1)

# %% [markdown]
# ## Modeling:

# %%
model = keras.Sequential()

model.add(Conv2D(filters=16, kernel_size=(3, 3), padding='same', activation='selu',
                 input_shape=[28, 28, 1], kernel_initializer='he_normal', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(SpatialDropout2D(4/16))
model.add(MaxPool2D(2))

model.add(Conv2D(filters=32, kernel_size=(3, 3),
                 padding='same', activation='selu', kernel_initializer='he_normal', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(SpatialDropout2D(8/32))
model.add(MaxPool2D(2))

model.add(Flatten())
model.add(Dense(units=64, activation='selu', kernel_initializer='he_normal', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(Dense(units=10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 28, 28, 16)        160
# _________________________________________________________________
# batch_normalization (BatchNo (None, 28, 28, 16)        64
# _________________________________________________________________
# spatial_dropout2d (SpatialDr (None, 28, 28, 16)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 32)        4640
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 14, 14, 32)        128
# _________________________________________________________________
# spatial_dropout2d_1 (Spatial (None, 14, 14, 32)        0
# ...

# %%
opt=Adam(learning_rate=0.001)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', patience=10, mode='auto')
model.compile(optimizer=opt,loss='sparse_categorical_crossentropy',metrics=['sparse_categorical_accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=50, batch_size=256, validation_data=(X_val,y_val),callbacks=[reduce_lr])
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/50
# 48000/48000 [==============================] - 6s 131us/sample - loss: 2.0635 - sparse_categorical_accuracy: 0.7755 - val_loss: 1.2588 - val_sparse_categorical_accuracy: 0.8496
# Epoch 2/50
# 48000/48000 [==============================] - 2s 45us/sample - loss: 0.9426 - sparse_categorical_accuracy: 0.8443 - val_loss: 0.7592 - val_sparse_categorical_accuracy: 0.8568
# Epoch 3/50
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.6655 - sparse_categorical_accuracy: 0.8592 - val_loss: 0.5659 - val_sparse_categorical_accuracy: 0.8771
# Epoch 4/50
# 48000/48000 [==============================] - 2s 45us/sample - loss: 0.5598 - sparse_categorical_accuracy: 0.8671 - val_loss: 0.4986 - val_sparse_categorical_accuracy: 0.8823
# Epoch 5/50
# ...

# %%
epoch_range=range(1,50+1)
plt.plot(epoch_range,history.history['sparse_categorical_accuracy'])
plt.plot(epoch_range,history.history['val_sparse_categorical_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
# plt.xticks([x for x in range(epoch+1)])
plt.legend(['Train','Val'],loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
# plt.xticks([x for x in range(epoch+1)])
plt.legend(['Train','Val'],loc='upper left')
plt.show()

# early stopping at epoch 6

# %% [markdown]
# ## Evaluation

# %%
y_pred = model.predict_classes(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.9121

# %%
mat = confusion_matrix(y_test,y_pred)
plot_confusion_matrix(conf_mat=mat,figsize=(8,8), class_names=class_names,show_normed=True)
# Out:
# (<Figure size 576x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x29f78e744e0>)
