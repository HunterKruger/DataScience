# %%
import tensorflow as tf
from tensorflow import keras  
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Dropout, Flatten, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn import datasets, metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,LabelEncoder
from tensorflow.keras.preprocessing import image

# %% [markdown]
# ## Load data

# %%
file = open('WISDM_ar_v1.1/WISDM_ar_v1.1_raw.txt')
lines = file.readlines()
processedList=[]
for i,line in enumerate(lines):
    try:
        line=line.split(',')  # before: 'line' is a whole row
                              # after; 'line' is a list, each item is seperated by ','
        last=line[5].split(';')[0]  # line[5] is ended by ';'     
                                    # line[5].split(';') is a list, [0] is a value, [1] is ';'
                                    # last = [0] of line[5].split(';') 
        last=last.strip() #strip() 方法用于移除字符串头尾指定的字符（默认为空格或换行符）或字符序列。
        if last=='':    # finish reading all rows
            break;
        temp=[line[0],line[1],line[2],line[3],line[4],last]
        processedList.append(temp)
    except:
        print('Error in line number: ',i)
# Out:
# Error in line number:  281873
# Error in line number:  281874
# Error in line number:  281875

# %%
columns = ['user','activity','time','x','y','z']

# %%
data = pd.DataFrame(data=processedList,columns=columns)
data.head()
# Out:
#   user activity            time            x          y            z
# 0   33  Jogging  49105962326000   -0.6946377  12.680544   0.50395286
# 1   33  Jogging  49106062271000     5.012288  11.264028   0.95342433
# 2   33  Jogging  49106112167000     4.903325  10.882658  -0.08172209
# 3   33  Jogging  49106222305000  -0.61291564  18.496431    3.0237172
# 4   33  Jogging  49106332290000   -1.1849703  12.108489     7.205164

# %%
data.shape
# Out:
# (343416, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 343416 entries, 0 to 343415
# Data columns (total 6 columns):
# user        343416 non-null object
# activity    343416 non-null object
# time        343416 non-null object
# x           343416 non-null object
# y           343416 non-null object
# z           343416 non-null object
# dtypes: object(6)
# memory usage: 15.7+ MB

# %%
data.isnull().sum()
# Out:
# user        0
# activity    0
# time        0
# x           0
# y           0
# z           0
# dtype: int64

# %%
data['activity'].value_counts()
# Out:
# Walking       137375
# Jogging       129392
# Upstairs       35137
# Downstairs     33358
# Sitting         4599
# Standing        3555
# Name: activity, dtype: int64

# %% [markdown]
# ## Balance data

# %%
data['x']=data['x'].astype('float')
data['y']=data['y'].astype('float')
data['z']=data['z'].astype('float')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 343416 entries, 0 to 343415
# Data columns (total 6 columns):
# user        343416 non-null object
# activity    343416 non-null object
# time        343416 non-null object
# x           343416 non-null float64
# y           343416 non-null float64
# z           343416 non-null float64
# dtypes: float64(3), object(3)
# memory usage: 15.7+ MB

# %%
freq = 20
activities = data['activity'].value_counts().index

# %%
def plot_activity(activity,data):
    fig, (ax0,ax1,ax2) = plt.subplots(nrows=3,figsize=(15,7),sharex=True)
    plot_axis(ax0,data['time'],data['x'],'X-axis')
    plot_axis(ax1,data['time'],data['y'],'Y-axis')
    plot_axis(ax2,data['time'],data['z'],'Z-axis')
    plt.subplots_adjust(hspace=0.2)
    fig.suptitle(activity)
    plt.subplots_adjust(top=0.90)
    plt.show()
def plot_axis(ax,x,y,title):
    ax.plot(x,y,'g')
    ax.set_title(title)
    ax.xaxis.set_visible(False)
    ax.set_ylim([min(y)-np.std(y),max(y)+np.std(y)])
    ax.grid(True)
for activity in activities:
    data_for_plot=data[(data['activity']==activity)][:freq*10]
    plot_activity(activity,data_for_plot)

# %%
df=data.drop(['user','time'],axis=1).copy()
df.head()
# Out:
#   activity         x          y         z
# 0  Jogging -0.694638  12.680544  0.503953
# 1  Jogging  5.012288  11.264028  0.953424
# 2  Jogging  4.903325  10.882658 -0.081722
# 3  Jogging -0.612916  18.496431  3.023717
# 4  Jogging -1.184970  12.108489  7.205164

# %%
df['activity'].value_counts()
# Out:
# Walking       137375
# Jogging       129392
# Upstairs       35137
# Downstairs     33358
# Sitting         4599
# Standing        3555
# Name: activity, dtype: int64

# %%
Walking = df[df['activity']=='Walking'].head(3555).copy()
Jogging = df[df['activity']=='Jogging'].head(3555).copy()
Upstairs = df[df['activity']=='Upstairs'].head(3555).copy()
Downstairs = df[df['activity']=='Downstairs'].head(3555).copy()
Sitting = df[df['activity']=='Sitting'].head(3555).copy()
Standing = df[df['activity']=='Standing'].head(3555).copy()

# %%
balanced_data = pd.DataFrame()
balanced_data=balanced_data.append([Walking,Jogging,Upstairs,Downstairs,Sitting,Standing])
balanced_data.shape
# Out:
# (21330, 4)

# %%
balanced_data['activity'].value_counts()
# Out:
# Upstairs      3555
# Jogging       3555
# Standing      3555
# Sitting       3555
# Downstairs    3555
# Walking       3555
# Name: activity, dtype: int64

# %%
balanced_data.head()
# Out:
#     activity         x          y         z
# 597  Walking  0.844462   8.008764  2.792171
# 598  Walking  1.116869   8.621680  3.786457
# 599  Walking -0.503953  16.657684  1.307553
# 600  Walking  4.794363  10.760075 -1.184970
# 601  Walking -0.040861   9.234595 -0.694638

# %%
label = LabelEncoder()
balanced_data['label']=label.fit_transform(balanced_data['activity'])
balanced_data.head()
# Out:
#     activity         x          y         z  label
# 597  Walking  0.844462   8.008764  2.792171      5
# 598  Walking  1.116869   8.621680  3.786457      5
# 599  Walking -0.503953  16.657684  1.307553      5
# 600  Walking  4.794363  10.760075 -1.184970      5
# 601  Walking -0.040861   9.234595 -0.694638      5

# %%
label.classes_
# Out:
# array(['Downstairs', 'Jogging', 'Sitting', 'Standing', 'Upstairs',
#        'Walking'], dtype=object)

# %% [markdown]
# ## Standarize data

# %%
X = balanced_data[['x','y','z']]
y = balanced_data['label']

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)
scaled_X = pd.DataFrame(data = X, columns=['x','y','z'])
scaled_X['label']=y.values
scaled_X.head()
# Out:
#           x         y         z  label
# 0  0.000503 -0.099190  0.337933      5
# 1  0.073590  0.020386  0.633446      5
# 2 -0.361275  1.588160 -0.103312      5
# 3  1.060258  0.437573 -0.844119      5
# 4 -0.237028  0.139962 -0.698386      5

# %% [markdown]
# ## Frame Preparation

# %%
import scipy.stats as stats

# %%
freq =20
frame_size=freq*4 #80, feed NN 80 samples a time
hop_size=freq*2  #40

# %%
def get_frames(df,frame_size,hop_size):
    N_FEATURES=3
    frames=[]
    labels=[]
    for i in range(0,len(df)-frame_size,hop_size): #start,end,step
        x=df['x'].values[i:i+frame_size]
        y=df['y'].values[i:i+frame_size]
        z=df['z'].values[i:i+frame_size]
        
        #Retrive the most often used label in this segment
        label=stats.mode(df['label'][i:i+frame_size])[0][0]  #mode:众数
        frames.append([x,y,z])
        labels.append(label)
        
    # Reshape segments
    frames=np.asarray(frames).reshape(-1,frame_size,N_FEATURES)
    labels=np.asarray(labels)
    return frames,labels

# %%
X,y=get_frames(scaled_X,frame_size,hop_size)

# %%
X.shape,y.shape #532=3555*6/40=samples*labels/hopSize
# Out:
# ((532, 80, 3), (532,))

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=0,stratify=y)
X_train.shape,X_test.shape
# Out:
# ((425, 80, 3), (107, 80, 3))

# %%
X_train=X_train.reshape(425, 80, 3,1)
X_test=X_test.reshape(107, 80, 3,1)

# %% [markdown]
# ## Build 2D CNN model

# %%
model=Sequential()

model.add(Conv2D(filters=16,kernel_size=(2,2),activation='relu',input_shape=X_train[0].shape))
model.add(Dropout(0.1))

model.add(Conv2D(filters=32,kernel_size=(2,2),activation='relu'))
model.add(Dropout(0.2))

model.add(Flatten())

model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(6,activation='softmax'))
# Out:
# WARNING:tensorflow:From C:\Utilities\Anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
model.compile(optimizer=Adam(learning_rate=0.001),loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
history=model.fit(X_train,y_train,epochs=10,validation_data=(X_test,y_test),verbose=1)
# Out:
# Train on 425 samples, validate on 107 samples
# Epoch 1/10
# 425/425 [==============================] - 2s 5ms/sample - loss: 1.6477 - acc: 0.2706 - val_loss: 1.3470 - val_acc: 0.6168
# Epoch 2/10
# 425/425 [==============================] - 0s 106us/sample - loss: 1.2626 - acc: 0.5341 - val_loss: 0.9415 - val_acc: 0.7196
# Epoch 3/10
# 425/425 [==============================] - 0s 106us/sample - loss: 0.8986 - acc: 0.7341 - val_loss: 0.6127 - val_acc: 0.8037
# Epoch 4/10
# 425/425 [==============================] - 0s 101us/sample - loss: 0.6786 - acc: 0.7647 - val_loss: 0.4298 - val_acc: 0.8785
# Epoch 5/10
# 425/425 [==============================] - 0s 106us/sample - loss: 0.4972 - acc: 0.8400 - val_loss: 0.3475 - val_acc: 0.8972
# Epoch 6/10
# 425/425 [==============================] - 0s 106us/sample - loss: 0.3702 - acc: 0.8800 - val_loss: 0.2907 - val_acc: 0.8879
# Epoch 7/10
# ...

# %% [markdown]
# ## Evaluation

# %%
epoch_range=range(1,10+1)
plt.plot(epoch_range,history.history['acc'])
plt.plot(epoch_range,history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Val'],loc='upper left')
plt.show()

plt.plot(epoch_range,history.history['loss'])
plt.plot(epoch_range,history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Val'],loc='upper left')
plt.show()

# %%
#neither overfitting nor underfitting, 9 epochs is optimal, acc=0.9

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
y_pred=model.predict_classes(X_test)
mat=confusion_matrix(y_test,y_pred)

# %%
plot_confusion_matrix(conf_mat=mat,class_names=label.classes_,show_normed=True,figsize=(7,7))
# Out:
# (<Figure size 504x504 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x20eaf746c50>)
