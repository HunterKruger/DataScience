# %%
import pandas as pd 
import numpy as np
from pprint import pprint
import joblib

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score 
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score

from sklearn.ensemble import RandomForestClassifier as RF
from xgboost import XGBClassifier as XGBC
from lightgbm import LGBMClassifier as LGBC

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler as RUS

# %% [markdown]
# ## Import data

# %%
train_origin = pd.read_csv('../data/featured_data/train.csv')
train_origin.shape
# Out:
# (260753, 297)

# %%
X_train_origin = train_origin.drop('QuoteConversion_Flag',axis=1)
y_train_origin = train_origin['QuoteConversion_Flag']

# %%
X_train_origin.shape,  y_train_origin.shape
# Out:
# ((260753, 296), (260753,))

# %% [markdown]
# ## Final iteration: under sampling + LGBC tuning

# %%
rus = RUS(random_state=1) 
X_train_res,y_train_res=rus.fit_resample(X_train_origin,y_train_origin)

# %%
X_train_res.shape, y_train_res.shape
# Out:
# ((97788, 296), (97788,))

# %%
param_LGBC = {
    'learning_rate': [0.01, 0.1, 1],
    'n_estimators': [20, 40],
    'max_depth': [4, 6, 8],
    'num_leaves': [20, 30, 40],
    'min_child_samples': [18, 19, 20, 21, 22],
    'min_child_weight': [0.001, 0.002],
    'feature_fraction': [0.6, 0.8, 1],
    'bagging_fraction': [0.8, 0.9, 1],
    'bagging_freq': [2, 3, 4],
    'cat_smooth': [0, 10, 20]
}
lgbc = LGBC()
clf_lgbc = RandomizedSearchCV(lgbc, param_distributions = param_LGBC, cv=3,n_iter=40, n_jobs=-1)
clf_lgbc.fit(X_train_res, y_train_res)
# Out:
# RandomizedSearchCV(cv=3, error_score=nan,
#                    estimator=LGBMClassifier(boosting_type='gbdt',
#                                             class_weight=None,
#                                             colsample_bytree=1.0,
#                                             importance_type='split',
#                                             learning_rate=0.1, max_depth=-1,
#                                             min_child_samples=20,
#                                             min_child_weight=0.001,
#                                             min_split_gain=0.0,
#                                             n_estimators=100, n_jobs=-1,
#                                             num_leaves=31, objective=None,
#                                             random_state=None, reg_alpha=0.0,
#                                             reg_lambda=0.0, sile...
#                    param_distributions={'bagging_fraction': [0.8, 0.9, 1],
#                                         'bagging_freq': [2, 3, 4],
#                                         'cat_smooth': [0, 10, 20],
#                                         'feature_fraction': [0.6, 0.8, 1],
#                                         'learning_rate': [0.01, 0.1, 1],
#                                         'max_depth': [4, 6, 8],
#                                         'min_child_samples': [18, 19, 20, 21,
#                                                               22],
#                                         'min_child_weight': [0.001, 0.002],
#                                         'n_estimators': [20, 40],
#                                         'num_leaves': [20, 30, 40]},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=False, scoring=None, verbose=0)

# %%
clf_lgbc.best_estimator_
# Out:
# LGBMClassifier(bagging_fraction=1, bagging_freq=2, boosting_type='gbdt',
#                cat_smooth=20, class_weight=None, colsample_bytree=1.0,
#                feature_fraction=0.6, importance_type='split', learning_rate=1,
#                max_depth=4, min_child_samples=18, min_child_weight=0.001,
#                min_split_gain=0.0, n_estimators=20, n_jobs=-1, num_leaves=30,
#                objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,
#                silent=True, subsample=1.0, subsample_for_bin=200000,
#                subsample_freq=0)

# %%
clf_lgbc.cv_results_
# Out:
# {'mean_fit_time': array([11.80660804, 10.18054303,  8.08536235,  8.11963701,  7.40771206,
#          6.32577697,  9.34397205,  9.35843301,  9.93049296,  6.44843547,
#          5.84738175,  7.08948302,  8.73938306,  5.36283739,  7.48543827,
#          5.1350522 ,  5.16575813,  7.57434082,  5.57659896,  6.12486267,
#          5.42443458,  5.95842894,  6.6205767 ,  5.54972188,  6.25267506,
#          5.17270716,  4.87337049,  5.63703553,  7.97144365,  8.04095928,
#          6.12503926,  5.35108217,  5.03112364,  7.51097902,  7.95025071,
#          5.12743823,  7.93787193,  5.72347562,  4.80335069,  5.67546097]),
#  'std_fit_time': array([0.22311171, 0.67725563, 1.1759908 , 0.17417809, 0.11414198,
#         0.23503971, 0.3219782 , 0.14692747, 0.27511704, 0.40773481,
#         0.03133447, 0.15923109, 0.25446308, 0.14614858, 0.29310689,
#         0.09994276, 0.19524765, 0.06986526, 0.16217849, 0.14298995,
#         0.14596904, 0.11180176, 0.18328945, 0.18743012, 0.09864331,
#         0.13337366, 0.04869075, 0.03437734, 0.14976863, 0.11150766,
#         0.07961861, 0.13861157, 0.17469476, 0.15256031, 0.05698963,
#         0.08203439, 0.16830031, 0.05687382, 0.04645949, 0.0359978 ]),
#  'mean_score_time': array([0.76036   , 0.64440624, 0.56968737, 0.70234728, 0.5208439 ,
#         0.53104591, 0.66461865, 0.68423978, 0.50632278, 0.44165794,
#         0.43478497, 0.52718012, 0.50626397, 0.42282605, 0.50005833,
#         0.41758307, 0.43425488, 0.48307467, 0.44375237, 0.44087783,
#         0.42972072, 0.44325598, 0.50598025, 0.43070245, 0.43625657,
#         0.42967224, 0.42818101, 0.42169484, 0.48487504, 0.47027644,
#         0.45892429, 0.41541163, 0.40844138, 0.52534469, 0.49568995,
#         0.41408745, 0.51620038, 0.43208774, 0.41787966, 0.3638494 ]),
#  'std_score_time': array([0.05194127, 0.05467551, 0.07801537, 0.00644478, 0.0718802 ,
#         0.06911399, 0.04510969, 0.14474509, 0.02576104, 0.0127298 ,
#         0.01802183, 0.02750114, 0.00414567, 0.00470831, 0.01932434,
#         0.01884652, 0.01258773, 0.01203042, 0.00979548, 0.00652   ,
#         0.01164864, 0.00854385, 0.01365129, 0.00426843, 0.01151456,
#         0.01498357, 0.00448677, 0.00776622, 0.01484844, 0.00641671,
#         0.01690543, 0.0044682 , 0.02203991, 0.02320907, 0.01029263,
#         0.0095513 , 0.00376278, 0.00751148, 0.00664234, 0.0136381 ]),
#  'param_num_leaves': masked_array(data=[20, 20, 30, 40, 40, 30, 40, 40, 30, 40, 40, 40, 40, 20,
#                     30, 30, 30, 20, 30, 40, 20, 40, 30, 20, 30, 30, 20, 40,
#                     20, 20, 40, 40, 20, 40, 40, 30, 40, 20, 30, 40],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[40, 20, 20, 40, 20, 20, 40, 40, 40, 20, 20, 40, 40, 20,
#                     40, 20, 20, 40, 20, 20, 20, 20, 40, 20, 20, 20, 20, 20,
#                     40, 40, 40, 20, 20, 40, 40, 20, 40, 20, 20, 20],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_child_weight': masked_array(data=[0.001, 0.002, 0.001, 0.001, 0.002, 0.001, 0.002, 0.002,
#                     0.001, 0.001, 0.002, 0.002, 0.002, 0.001, 0.001, 0.002,
#                     0.001, 0.001, 0.002, 0.001, 0.002, 0.002, 0.001, 0.002,
#                     0.001, 0.001, 0.001, 0.002, 0.001, 0.001, 0.002, 0.001,
#                     0.002, 0.001, 0.001, 0.002, 0.002, 0.001, 0.001, 0.002],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_child_samples': masked_array(data=[22, 21, 18, 19, 20, 19, 19, 20, 19, 18, 19, 22, 18, 22,
#                     21, 18, 22, 22, 21, 21, 18, 21, 20, 19, 18, 22, 19, 19,
#                     20, 22, 18, 20, 21, 21, 19, 18, 21, 18, 18, 20],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[4, 6, 8, 6, 8, 6, 8, 6, 6, 6, 6, 6, 8, 4, 6, 4, 6, 6,
#                     6, 8, 8, 8, 8, 6, 8, 4, 6, 6, 6, 6, 4, 4, 4, 8, 6, 4,
#                     6, 6, 4, 6],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_learning_rate': masked_array(data=[0.01, 0.01, 1, 0.1, 1, 0.01, 1, 1, 0.1, 0.01, 0.1,
#                     0.01, 0.01, 0.01, 0.1, 0.01, 1, 0.1, 1, 0.01, 0.01,
#                     0.1, 1, 0.1, 0.01, 1, 1, 0.1, 0.01, 0.01, 1, 1, 0.01,
#                     1, 1, 0.01, 1, 0.1, 1, 0.1],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_feature_fraction': masked_array(data=[0.6, 1, 0.6, 0.6, 1, 0.8, 0.8, 1, 1, 1, 0.8, 0.6, 0.8,
#                     0.8, 0.8, 0.8, 0.6, 0.8, 0.6, 0.8, 0.6, 0.8, 0.6, 0.8,
#                     1, 0.8, 0.6, 0.8, 1, 1, 0.8, 1, 0.6, 0.8, 1, 0.8, 1, 1,
#                     0.6, 0.8],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_cat_smooth': masked_array(data=[10, 10, 10, 10, 20, 10, 10, 20, 20, 10, 0, 10, 0, 0,
#                     10, 20, 20, 0, 10, 0, 20, 10, 0, 20, 0, 0, 20, 10, 10,
#                     20, 20, 0, 10, 10, 10, 10, 10, 10, 20, 10],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_bagging_freq': masked_array(data=[4, 2, 3, 4, 2, 2, 2, 3, 4, 3, 3, 4, 2, 2, 2, 3, 2, 4,
#                     2, 3, 2, 2, 3, 2, 3, 3, 2, 3, 3, 3, 3, 4, 2, 4, 4, 4,
#                     4, 3, 2, 4],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_bagging_fraction': masked_array(data=[0.9, 0.8, 0.9, 0.8, 1, 0.8, 0.9, 0.8, 0.9, 0.9, 1, 0.9,
#                     0.9, 0.9, 0.9, 0.8, 0.9, 1, 0.9, 0.8, 0.8, 0.8, 0.9,
#                     0.9, 1, 0.9, 1, 0.9, 0.9, 0.9, 1, 0.9, 0.9, 1, 1, 1, 1,
#                     0.8, 1, 1],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'num_leaves': 20,
#    'n_estimators': 40,
#    'min_child_weight': 0.001,
#    'min_child_samples': 22,
#    'max_depth': 4,
#    'learning_rate': 0.01,
#    'feature_fraction': 0.6,
#    'cat_smooth': 10,
#    'bagging_freq': 4,
#    'bagging_fraction': 0.9},
#   {'num_leaves': 20,
#    'n_estimators': 20,
#    'min_child_weight': 0.002,
#    'min_child_samples': 21,
#    'max_depth': 6,
#    'learning_rate': 0.01,
#    'feature_fraction': 1,
#    'cat_smooth': 10,
#    'bagging_freq': 2,
#    'bagging_fraction': 0.8},
#   {'num_leaves': 30,
#    'n_estimators': 20,
#    'min_child_weight': 0.001,
#    'min_child_samples': 18,
#    'max_depth': 8,
#    'learning_rate': 1,
#    'feature_fraction': 0.6,
#    'cat_smooth': 10,
#    'bagging_freq': 3,
#    'bagging_fraction': 0.9},
#   {'num_leaves': 40,
#    'n_estimators': 40,
#    'min_child_weight': 0.001,
#    'min_child_samples': 19,
#    'max_depth': 6,
#    'learning_rate': 0.1,
#    'feature_fraction': 0.6,
#    'cat_smooth': 10,
#    'bagging_freq': 4,
#    'bagging_fraction': 0.8},
#   {'num_leaves': 40,
#    'n_estimators': 20,
#    'min_child_weight': 0.002,
#    'min_child_samples': 20,
#    'max_depth': 8,
#    'learning_rate': 1,
#    'feature_fraction': 1,
#    'cat_smooth': 20,
#    'bagging_freq': 2,
#    'bagging_fraction': 1},
#   {'num_leaves': 30,
#    'n_estimators': 20,
#    'min_child_weight': 0.001,
#    'min_child_samples': 19,
#    'max_depth': 6,
#    'learning_rate': 0.01,
#    'feature_fraction': 0.8,
#    'cat_smooth': 10,
#    'bagging_freq': 2,
#    'bagging_fraction': 0.8},
#   {'num_leaves': 40,
#    'n_estimators': 40,
#    'min_child_weight': 0.002,
#    'min_child_samples': 19,
#    'max_depth': 8,
#    'learning_rate': 1,
#    'feature_fraction': 0.8,
#    'cat_smooth': 10,
#    'bagging_freq': 2,
#    'bagging_fraction': 0.9},
#   {'num_leaves': 40,
#    'n_estimators': 40,
#    'min_child_weight': 0.002,
#    'min_child_samples': 20,
#    'max_depth': 6,
#    'learning_rate': 1,
#    'feature_fraction': 1,
#    'cat_smooth': 20,
#    'bagging_freq': 3,
#    'bagging_fraction': 0.8},
#   {'num_leaves': 30,
#    'n_estimators': 40,
#    'min_child_weight': 0.001,
#    'min_child_samples': 19,
#    'max_depth': 6,
#    'learning_rate': 0.1,
#    'feature_fraction': 1,
#    'cat_smooth': 20,
#    'bagging_freq': 4,
#    'bagging_fraction': 0.9},
#   {'num_leaves': 40,
#    'n_estimators': 20,
#    'min_child_weight': 0.001,
#    'min_child_samples': 18,
#    'max_depth': 6,
#    'learning_rate': 0.01,
#    'feature_fraction': 1,
#    'cat_smooth': 10,
#    'bagging_freq': 3,
#    'bagging_fraction': 0.9},
#   {'num_leaves': 40,
#    'n_estimators': 20,
#    'min_child_weight': 0.002,
#    'min_child_samples': 19,
#    'max_depth': 6,
#    'learning_rate': 0.1,
#    'feature_fraction': 0.8,
#    'cat_smooth': 0,
#    'bagging_freq': 3,
#    'bagging_fraction': 1},
#   {'num_leaves': 40,
#    'n_estimators': 40,
#    'min_child_weight': 0.002,
#    'min_child_samples': 22,
#    'max_depth': 6,
#    'learning_rate': 0.01,
#    'feature_fraction': 0.6,
#    'cat_smooth': 10,
#    'bagging_freq': 4,
#    'bagging_fraction': 0.9},
#   {'num_leaves': 40,
#    'n_estimators': 40,
#    'min_child_weight': 0.002,
#    'min_child_samples': 18,
#    'max_depth': 8,
#    'learning_rate': 0.01,
#    'feature_fraction': 0.8,
#    'cat_smooth': 0,
#    'bagging_freq': 2,
#    'bagging_fraction': 0.9},
#   {'num_leaves': 20,
#    'n_estimators': 20,
#    'min_child_weight': 0.001,
#    'min_child_samples': 22,
#    'max_depth': 4,
#    'learning_rate': 0.01,
#    'feature_fraction': 0.8,
#    'cat_smooth': 0,
#    'bagging_freq': 2,
#    'bagging_fraction': 0.9},
#   {'num_leaves': 30,
#    'n_estimators': 40,
#    'min_child_weight': 0.001,
#    'min_child_samples': 21,
#    'max_depth': 6,
#    'learning_rate': 0.1,
#    'feature_fraction': 0.8,
#    'cat_smooth': 10,
#    'bagging_freq': 2,
#    'bagging_fraction': 0.9},
#   {'num_leaves': 30,
#    'n_estimators': 20,
#    'min_child_weight': 0.002,
#    'min_child_samples': 18,
#    'max_depth': 4,
#    'learning_rate': 0.01,
#    'feature_fraction': 0.8,
#    'cat_smooth': 20,
#    'bagging_freq': 3,
#    'bagging_fraction': 0.8},
#   {'num_leaves': 30,
#    'n_estimators': 20,
#    'min_child_weight': 0.001,
#    'min_child_samples': 22,
#    'max_depth': 6,
#    'learning_rate': 1,
#    'feature_fraction': 0.6,
#    'cat_smooth': 20,
#    'bagging_freq': 2,
#    'bagging_fraction': 0.9},
#   {'num_leaves': 20,
#    'n_estimators': 40,
#    'min_child_weight': 0.001,
#    'min_child_samples': 22,
#    'max_depth': 6,
#    'learning_rate': 0.1,
#    'feature_fraction': 0.8,
#    'cat_smooth': 0,
#    'bagging_freq': 4,
#    'bagging_fraction': 1},
#   {'num_leaves': 30,
#    'n_estimators': 20,
#    'min_child_weight': 0.002,
#    'min_child_samples': 21,
#    'max_depth': 6,
#    'learning_rate': 1,
#    'feature_fraction': 0.6,
#    'cat_smooth': 10,
#    'bagging_freq': 2,
#    'bagging_fraction': 0.9},
#   {'num_leaves': 40,
#    'n_estimators': 20,
#    'min_child_weight': 0.001,
#    'min_child_samples': 21,
#    'max_depth': 8,
#    'learning_rate': 0.01,
#    'feature_fraction': 0.8,
#    'cat_smooth': 0,
#    'bagging_freq': 3,
#    'bagging_fraction': 0.8},
#   {'num_leaves': 20,
#    'n_estimators': 20,
#    'min_child_weight': 0.002,
#    'min_child_samples': 18,
#    'max_depth': 8,
#    'learning_rate': 0.01,
#    'feature_fraction': 0.6,
#    'cat_smooth': 20,
#    'bagging_freq': 2,
#    'bagging_fraction': 0.8},
#   {'num_leaves': 40,
#    'n_estimators': 20,
#    'min_child_weight': 0.002,
#    'min_child_samples': 21,
#    'max_depth': 8,
#    'learning_rate': 0.1,
#    'feature_fraction': 0.8,
#    'cat_smooth': 10,
#    'bagging_freq': 2,
#    'bagging_fraction': 0.8},
#   {'num_leaves': 30,
#    'n_estimators': 40,
#    'min_child_weight': 0.001,
#    'min_child_samples': 20,
#    'max_depth': 8,
#    'learning_rate': 1,
#    'feature_fraction': 0.6,
#    'cat_smooth': 0,
#    'bagging_freq': 3,
#    'bagging_fraction': 0.9},
#   {'num_leaves': 20,
#    'n_estimators': 20,
#    'min_child_weight': 0.002,
#    'min_child_samples': 19,
#    'max_depth': 6,
#    'learning_rate': 0.1,
#    'feature_fraction': 0.8,
#    'cat_smooth': 20,
#    'bagging_freq': 2,
#    'bagging_fraction': 0.9},
#   {'num_leaves': 30,
#    'n_estimators': 20,
#    'min_child_weight': 0.001,
#    'min_child_samples': 18,
#    'max_depth': 8,
#    'learning_rate': 0.01,
#    'feature_fraction': 1,
#    'cat_smooth': 0,
#    'bagging_freq': 3,
#    'bagging_fraction': 1},
#   {'num_leaves': 30,
#    'n_estimators': 20,
#    'min_child_weight': 0.001,
#    'min_child_samples': 22,
#    'max_depth': 4,
#    'learning_rate': 1,
#    'feature_fraction': 0.8,
#    'cat_smooth': 0,
#    'bagging_freq': 3,
#    'bagging_fraction': 0.9},
#   {'num_leaves': 20,
#    'n_estimators': 20,
#    'min_child_weight': 0.001,
#    'min_child_samples': 19,
#    'max_depth': 6,
#    'learning_rate': 1,
#    'feature_fraction': 0.6,
#    'cat_smooth': 20,
#    'bagging_freq': 2,
#    'bagging_fraction': 1},
#   {'num_leaves': 40,
#    'n_estimators': 20,
#    'min_child_weight': 0.002,
#    'min_child_samples': 19,
#    'max_depth': 6,
#    'learning_rate': 0.1,
#    'feature_fraction': 0.8,
#    'cat_smooth': 10,
#    'bagging_freq': 3,
#    'bagging_fraction': 0.9},
#   {'num_leaves': 20,
#    'n_estimators': 40,
#    'min_child_weight': 0.001,
#    'min_child_samples': 20,
#    'max_depth': 6,
#    'learning_rate': 0.01,
#    'feature_fraction': 1,
#    'cat_smooth': 10,
#    'bagging_freq': 3,
#    'bagging_fraction': 0.9},
#   {'num_leaves': 20,
#    'n_estimators': 40,
#    'min_child_weight': 0.001,
#    'min_child_samples': 22,
#    'max_depth': 6,
#    'learning_rate': 0.01,
#    'feature_fraction': 1,
#    'cat_smooth': 20,
#    'bagging_freq': 3,
#    'bagging_fraction': 0.9},
#   {'num_leaves': 40,
#    'n_estimators': 40,
#    'min_child_weight': 0.002,
#    'min_child_samples': 18,
#    'max_depth': 4,
#    'learning_rate': 1,
#    'feature_fraction': 0.8,
#    'cat_smooth': 20,
#    'bagging_freq': 3,
#    'bagging_fraction': 1},
#   {'num_leaves': 40,
#    'n_estimators': 20,
#    'min_child_weight': 0.001,
#    'min_child_samples': 20,
#    'max_depth': 4,
#    'learning_rate': 1,
#    'feature_fraction': 1,
#    'cat_smooth': 0,
#    'bagging_freq': 4,
#    'bagging_fraction': 0.9},
#   {'num_leaves': 20,
#    'n_estimators': 20,
#    'min_child_weight': 0.002,
#    'min_child_samples': 21,
#    'max_depth': 4,
#    'learning_rate': 0.01,
#    'feature_fraction': 0.6,
#    'cat_smooth': 10,
#    'bagging_freq': 2,
#    'bagging_fraction': 0.9},
#   {'num_leaves': 40,
#    'n_estimators': 40,
#    'min_child_weight': 0.001,
#    'min_child_samples': 21,
#    'max_depth': 8,
#    'learning_rate': 1,
#    'feature_fraction': 0.8,
#    'cat_smooth': 10,
#    'bagging_freq': 4,
#    'bagging_fraction': 1},
#   {'num_leaves': 40,
#    'n_estimators': 40,
#    'min_child_weight': 0.001,
#    'min_child_samples': 19,
#    'max_depth': 6,
#    'learning_rate': 1,
#    'feature_fraction': 1,
#    'cat_smooth': 10,
#    'bagging_freq': 4,
#    'bagging_fraction': 1},
#   {'num_leaves': 30,
#    'n_estimators': 20,
#    'min_child_weight': 0.002,
#    'min_child_samples': 18,
#    'max_depth': 4,
#    'learning_rate': 0.01,
#    'feature_fraction': 0.8,
#    'cat_smooth': 10,
#    'bagging_freq': 4,
#    'bagging_fraction': 1},
#   {'num_leaves': 40,
#    'n_estimators': 40,
#    'min_child_weight': 0.002,
#    'min_child_samples': 21,
#    'max_depth': 6,
#    'learning_rate': 1,
#    'feature_fraction': 1,
#    'cat_smooth': 10,
#    'bagging_freq': 4,
#    'bagging_fraction': 1},
#   {'num_leaves': 20,
#    'n_estimators': 20,
#    'min_child_weight': 0.001,
#    'min_child_samples': 18,
#    'max_depth': 6,
#    'learning_rate': 0.1,
#    'feature_fraction': 1,
#    'cat_smooth': 10,
#    'bagging_freq': 3,
#    'bagging_fraction': 0.8},
#   {'num_leaves': 30,
#    'n_estimators': 20,
#    'min_child_weight': 0.001,
#    'min_child_samples': 18,
#    'max_depth': 4,
#    'learning_rate': 1,
#    'feature_fraction': 0.6,
#    'cat_smooth': 20,
#    'bagging_freq': 2,
#    'bagging_fraction': 1},
#   {'num_leaves': 40,
#    'n_estimators': 20,
#    'min_child_weight': 0.002,
#    'min_child_samples': 20,
#    'max_depth': 6,
#    'learning_rate': 0.1,
#    'feature_fraction': 0.8,
#    'cat_smooth': 10,
#    'bagging_freq': 4,
#    'bagging_fraction': 1}],
#  'split0_test_score': array([0.84286416, 0.86335747, 0.87829795, 0.88035342, 0.87618113,
#         0.86728433, 0.8693398 , 0.86958523, 0.87888084, 0.86332679,
#         0.87455516, 0.8691864 , 0.87504602, 0.84271076, 0.88041477,
#         0.84271076, 0.87863542, 0.8799546 , 0.87829795, 0.87415634,
#         0.87099644, 0.87796049, 0.86906369, 0.87409498, 0.87219291,
#         0.88185667, 0.88035342, 0.87430973, 0.86338815, 0.86338815,
#         0.88136581, 0.88403485, 0.84277212, 0.81623512, 0.87249969,
#         0.84271076, 0.87259173, 0.8742177 , 0.88158056, 0.8744938 ]),
#  'split1_test_score': array([0.84470487, 0.86519818, 0.87645723, 0.88302246, 0.87476991,
#         0.86820469, 0.85893975, 0.87412566, 0.88010799, 0.86519818,
#         0.87676402, 0.87197816, 0.87670266, 0.84479691, 0.88056817,
#         0.84479691, 0.87348141, 0.88105903, 0.87532213, 0.87608909,
#         0.8740643 , 0.88090563, 0.87090441, 0.87575163, 0.87412566,
#         0.88280771, 0.87946374, 0.87559823, 0.86535158, 0.86535158,
#         0.88317585, 0.88213278, 0.84482759, 0.82826114, 0.8661799 ,
#         0.84479691, 0.87050558, 0.87556755, 0.8833906 , 0.87676402]),
#  'split2_test_score': array([0.84630016, 0.86378697, 0.87418702, 0.88029206, 0.87400295,
#         0.86621058, 0.86053503, 0.83703522, 0.87897288, 0.86375629,
#         0.87418702, 0.86808197, 0.87403362, 0.84402994, 0.88004663,
#         0.84402994, 0.87572095, 0.87921831, 0.8683274 , 0.87378819,
#         0.87154866, 0.8780832 , 0.85013499, 0.87409498, 0.87326666,
#         0.88035342, 0.87872745, 0.87409498, 0.86406308, 0.86406308,
#         0.87746963, 0.87569027, 0.84418334, 0.84335501, 0.87311327,
#         0.84402994, 0.8750767 , 0.87256105, 0.88056817, 0.87418702]),
#  'mean_test_score': array([0.84462306, 0.86411421, 0.87631407, 0.88122264, 0.87498466,
#         0.8672332 , 0.86293819, 0.8602487 , 0.87932057, 0.86409375,
#         0.87516873, 0.86974884, 0.87526077, 0.84384587, 0.88034319,
#         0.84384587, 0.87594592, 0.88007731, 0.87398249, 0.87467787,
#         0.87220313, 0.87898311, 0.86336769, 0.8746472 , 0.87319508,
#         0.8816726 , 0.87951487, 0.87466765, 0.8642676 , 0.8642676 ,
#         0.88067043, 0.8806193 , 0.84392768, 0.82928376, 0.87059762,
#         0.84384587, 0.87272467, 0.87411543, 0.88184644, 0.87514828]),
#  'std_test_score': array([0.00140394, 0.00078629, 0.00168133, 0.00127291, 0.00090211,
#         0.00081489, 0.00457323, 0.01651874, 0.00055805, 0.00080039,
#         0.00113801, 0.00163958, 0.00110016, 0.00086155, 0.00021885,
#         0.00086155, 0.00211012, 0.00075646, 0.00417923, 0.00100914,
#         0.00133521, 0.00136035, 0.00938706, 0.00078095, 0.00079066,
#         0.00101038, 0.00066478, 0.00066384, 0.00081451, 0.00081451,
#         0.00238088, 0.00357081, 0.00085839, 0.01109524, 0.00313383,
#         0.00086155, 0.00186852, 0.00122953, 0.00116749, 0.00114935]),
#  'rank_test_score': array([35, 30, 11,  3, 16, 27, 33, 34,  9, 31, 14, 26, 13, 37,  6, 37, 12,
#          7, 21, 17, 24, 10, 32, 19, 22,  2,  8, 18, 28, 28,  4,  5, 36, 40,
#         25, 37, 23, 20,  1, 15], dtype=int32)}

# %% [markdown]
# ## Train the best model

# %%
best_lgbc = LGBC(bagging_fraction=1, bagging_freq=2, boosting_type='gbdt',
               cat_smooth=20, class_weight=None, colsample_bytree=1.0,
               feature_fraction=0.6, importance_type='split', learning_rate=1,
               max_depth=4, min_child_samples=18, min_child_weight=0.001,
               min_split_gain=0.0, n_estimators=20, n_jobs=-1, num_leaves=30,
               objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,
               silent=True, subsample=1.0, subsample_for_bin=200000,
               subsample_freq=0)

# %%
best_lgbc.fit(X_train_res,y_train_res)
# Out:
# LGBMClassifier(bagging_fraction=1, bagging_freq=2, boosting_type='gbdt',
#                cat_smooth=20, class_weight=None, colsample_bytree=1.0,
#                feature_fraction=0.6, importance_type='split', learning_rate=1,
#                max_depth=4, min_child_samples=18, min_child_weight=0.001,
#                min_split_gain=0.0, n_estimators=20, n_jobs=-1, num_leaves=30,
#                objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,
#                silent=True, subsample=1.0, subsample_for_bin=200000,
#                subsample_freq=0)

# %%
joblib.dump(best_lgbc,'../models/lgbc.m')
# Out:
# ['../models/lgbc.m']
