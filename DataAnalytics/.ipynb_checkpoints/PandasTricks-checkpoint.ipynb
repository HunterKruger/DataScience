# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## create an example DataFrame

# %%
df = pd.DataFrame({'col 1':[100,200], 'col 2':[300,400]})
df
# Out:
#    col 1  col 2
# 0    100    300
# 1    200    400

# %%
df2=pd.DataFrame(np.random.rand(4,8))
df2
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.733386  0.314736  0.611414  0.085937  0.442162  0.312778  0.631237
# 1  0.415539  0.734389  0.477979  0.166405  0.331119  0.932534  0.291899
# 2  0.933381  0.892655  0.465351  0.811387  0.914572  0.060488  0.245457
# 3  0.793883  0.514876  0.247964  0.645052  0.022993  0.962640  0.398748
#
#           7
# 0  0.817120
# 1  0.006477
# 2  0.267264
# 3  0.626657

# %%
df3=pd.DataFrame(np.random.rand(4,8),columns=list('abcdefgh'))
df3
# Out:
#           a         b         c         d         e         f         g  \
# 0  0.485496  0.034854  0.343455  0.176475  0.035944  0.101071  0.705225
# 1  0.193622  0.029050  0.450104  0.609941  0.696285  0.223313  0.297436
# 2  0.443318  0.576508  0.932167  0.437408  0.420501  0.962495  0.276723
# 3  0.400860  0.210459  0.827242  0.975223  0.557269  0.583487  0.898812
#
#           h
# 0  0.043794
# 1  0.119226
# 2  0.748548
# 3  0.544572

# %% [markdown]
# ## rename columns

# %%
df = df.rename({'col 1':'col one', 'col 2':'col two'},axis='columns')
df
# Out:
#    col one  col two
# 0      100      300
# 1      200      400

# %%
df.columns=df.columns.str.replace(' ','_')
df
# Out:
#    col_one  col_two
# 0      100      300
# 1      200      400

# %%
df.add_prefix('X_')
# Out:
#    X_col_one  X_col_two
# 0        100        300
# 1        200        400

# %%
df.add_suffix('_Y')
# Out:
#    col_one_Y  col_two_Y
# 0        100        300
# 1        200        400

# %% [markdown]
# ## reverse row order

# %%
iris = pd.read_csv('iris.csv')
iris.head(5)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris.loc[::-1].head()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 149           5.9          3.0           5.1          1.8  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 145           6.7          3.0           5.2          2.3  Virginica

# %%
iris.loc[::-1].reset_index(drop=True).head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width    variety
# 0           5.9          3.0           5.1          1.8  Virginica
# 1           6.2          3.4           5.4          2.3  Virginica
# 2           6.5          3.0           5.2          2.0  Virginica
# 3           6.3          2.5           5.0          1.9  Virginica
# 4           6.7          3.0           5.2          2.3  Virginica

# %% [markdown]
# ## reverse column order

# %%
iris.loc[:,::-1].head()
# Out:
#   variety  petal.width  petal.length  sepal.width  sepal.length
# 0  Setosa          0.2           1.4          3.5           5.1
# 1  Setosa          0.2           1.4          3.0           4.9
# 2  Setosa          0.2           1.3          3.2           4.7
# 3  Setosa          0.2           1.5          3.1           4.6
# 4  Setosa          0.2           1.4          3.6           5.0

# %% [markdown]
# ## select columns by data type

# %%
iris.dtypes
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %%
iris.select_dtypes(include='number').head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
iris.select_dtypes(include='object').head()
# Out:
#   variety
# 0  Setosa
# 1  Setosa
# 2  Setosa
# 3  Setosa
# 4  Setosa

# %%
iris.select_dtypes(include=['object','number']).head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris.select_dtypes(exclude='object').head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %% [markdown]
# ## convert strings to numbers

# %%
df4 = pd.DataFrame({'col 1':['100','200','300'],'col 2':['400','500','600'],'col 3':['700','800','-']})
df4
# Out:
#   col 1 col 2 col 3
# 0   100   400   700
# 1   200   500   800
# 2   300   600     -

# %%
df4.dtypes
# Out:
# col 1    object
# col 2    object
# col 3    object
# dtype: object

# %%
df4.astype({'col 1':'int','col 2':'int'}).dtypes
# Out:
# col 1     int64
# col 2     int64
# col 3    object
# dtype: object

# %%
pd.to_numeric(df4['col 3'],errors='coerce').fillna(0)
# Out:
# 0    700.0
# 1    800.0
# 2      0.0
# Name: col 3, dtype: float64

# %%
df4=df4.apply(pd.to_numeric, errors='coerce').fillna(0)
df4
# Out:
#    col 1  col 2  col 3
# 0    100    400  700.0
# 1    200    500  800.0
# 2    300    600    0.0

# %%
df4.dtypes
# Out:
# col 1      int64
# col 2      int64
# col 3    float64
# dtype: object

# %% [markdown]
# ## reduce DataFrame size

# %%
iris.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal.length    150 non-null float64
# sepal.width     150 non-null float64
# petal.length    150 non-null float64
# petal.width     150 non-null float64
# variety         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 14.4 KB

# %%
cols=['sepal.length','sepal.width']
smallIris=pd.read_csv('iris.csv',usecols=cols)
smallIris.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 2 columns):
# sepal.length    150 non-null float64
# sepal.width     150 non-null float64
# dtypes: float64(2)
# memory usage: 2.5 KB

# %%
dtypes = {'variety':'category'}
smallerIris=pd.read_csv('iris.csv',dtype=dtypes)
smallerIris.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal.length    150 non-null float64
# sepal.width     150 non-null float64
# petal.length    150 non-null float64
# petal.width     150 non-null float64
# variety         150 non-null category
# dtypes: category(1), float64(4)
# memory usage: 5.2 KB

# %% [markdown]
# ## create DataFrame from clipboard

# %%
df = pd.read_clipboard()
df
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa

# %% [markdown]
# ## split a DataFrame into two random subsets

# %%
iris = pd.read_csv('iris.csv')
len(iris)
# Out:
# 150

# %%
iris1 = iris.sample(frac=0.75, random_state=1234)
iris2 = iris.drop(iris1.index)

# %%
len(iris1)+len(iris2)
# Out:
# 150

# %%
iris1.index.sort_values()
# Out:
# Int64Index([  0,   1,   4,   5,   6,   7,   8,   9,  10,  11,
#             ...
#             138, 140, 141, 142, 144, 145, 146, 147, 148, 149],
#            dtype='int64', length=112)

# %%
iris2.index.sort_values()
# Out:
# Int64Index([  2,   3,  12,  14,  19,  23,  26,  30,  34,  37,  38,  46,  47,
#              50,  53,  60,  65,  69,  71,  75,  76,  80,  81, 106, 107, 112,
#             115, 116, 118, 120, 121, 124, 127, 128, 129, 136, 139, 143],
#            dtype='int64')

# %%
iris1.head()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 91            6.1          3.0           4.6          1.4  Versicolor
# 63            6.1          2.9           4.7          1.4  Versicolor
# 103           6.3          2.9           5.6          1.8   Virginica
# 6             4.6          3.4           1.4          0.3      Setosa
# 59            5.2          2.7           3.9          1.4  Versicolor

# %% [markdown]
# ## filter a DataFrame by multiple catagories

# %%
movies = pd.read_csv('movie.csv')
movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                     723       178
# 1  Color     Gore Verbinski                     302       169
# 2  Color         Sam Mendes                     602       148
# 3  Color  Christopher Nolan                     813       164
# 4     49        Doug Walker                      49        49
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                        0                     855  Joel David Moore
# 1                      563                    1000     Orlando Bloom
# 2                        0                     161      Rory Kinnear
# 3                    22000                   23000    Christian Bale
# 4                      131                      49        Rob Walker
#
#    actor_1_facebook_likes      gross                           genres  ...  \
# 0                    1000  760505847  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                   40000  309404152         Action|Adventure|Fantasy  ...
# 2                   11000  200074175        Action|Adventure|Thriller  ...
# 3                   27000  448130642                  Action|Thriller  ...
# 4                     131         49                      Documentary  ...
#
#   num_user_for_reviews language  country  content_rating     budget  \
# 0                 3054  English      USA           PG-13  237000000
# 1                 1238  English      USA           PG-13  300000000
# 2                  994  English       UK           PG-13  245000000
# 3                 2701  English      USA           PG-13  250000000
# 4                   49       49       49              49         49
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0        2009                    936        7.9          1.78
# 1        2007                   5000        7.1          2.35
# 2        2015                    393        6.8          2.35
# 3        2012                  23000        8.5          2.35
# 4          49                     12        7.1         49.00
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %%
movies.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
movies[movies.country.isin(['USA','UK'])].head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                     723       178
# 1  Color     Gore Verbinski                     302       169
# 2  Color         Sam Mendes                     602       148
# 3  Color  Christopher Nolan                     813       164
# 5  Color     Andrew Stanton                     462       132
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                        0                     855  Joel David Moore
# 1                      563                    1000     Orlando Bloom
# 2                        0                     161      Rory Kinnear
# 3                    22000                   23000    Christian Bale
# 5                      475                     530   Samantha Morton
#
#    actor_1_facebook_likes      gross                           genres  ...  \
# 0                    1000  760505847  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                   40000  309404152         Action|Adventure|Fantasy  ...
# 2                   11000  200074175        Action|Adventure|Thriller  ...
# 3                   27000  448130642                  Action|Thriller  ...
# 5                     640   73058679          Action|Adventure|Sci-Fi  ...
#
#   num_user_for_reviews language  country  content_rating     budget  \
# 0                 3054  English      USA           PG-13  237000000
# 1                 1238  English      USA           PG-13  300000000
# 2                  994  English       UK           PG-13  245000000
# 3                 2701  English      USA           PG-13  250000000
# 5                  738  English      USA           PG-13  263700000
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0        2009                    936        7.9          1.78
# 1        2007                   5000        7.1          2.35
# 2        2015                    393        6.8          2.35
# 3        2012                  23000        8.5          2.35
# 5        2012                    632        6.6          2.35
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 5                24000
#
# [5 rows x 28 columns]

# %%
movies[~movies.country.isin(['USA','UK'])].head()
# Out:
#     color  director_name  num_critic_for_reviews  duration  \
# 4      49    Doug Walker                      49        49
# 20  Color  Peter Jackson                     422       164
# 25  Color  Peter Jackson                     446       201
# 34  Color   Brett Ratner                     334       104
# 50  Color   Baz Luhrmann                     490       143
#
#     director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 4                       131                      49          Rob Walker
# 20                        0                     773          Adam Brown
# 25                        0                      84  Thomas Kretschmann
# 34                      420                     560      Kelsey Grammer
# 50                     1000                      77   Elizabeth Debicki
#
#     actor_1_facebook_likes      gross  \
# 4                      131         49
# 20                    5000  255108370
# 25                    6000  218051260
# 34                   20000  234360014
# 50                   29000  144812796
#
#                                       genres  ... num_user_for_reviews  \
# 4                                Documentary  ...                   49
# 20                         Adventure|Fantasy  ...                  802
# 25            Action|Adventure|Drama|Romance  ...                 2618
# 34  Action|Adventure|Fantasy|Sci-Fi|Thriller  ...                 1912
# 50                             Drama|Romance  ...                  753
#
#    language      country  content_rating     budget  title_year  \
# 4        49           49              49         49          49
# 20  English  New Zealand           PG-13  250000000        2014
# 25  English  New Zealand           PG-13  207000000        2005
# 34  English       Canada           PG-13  210000000        2006
# 50  English    Australia           PG-13  105000000        2013
#
#    actor_2_facebook_likes imdb_score  aspect_ratio movie_facebook_likes
# 4                      12        7.1         49.00                    0
# 20                    972        7.5          2.35                65000
# 25                    919        7.2          2.35                    0
# 34                    808        6.8          2.35                    0
# 50                    509        7.3          2.35               115000
#
# [5 rows x 28 columns]

# %% [markdown]
# ## filter a DataFrame by largest catagories

# %%
counts = movies.country.value_counts()
counts
# Out:
# USA                     3807
# UK                       448
# France                   154
# Canada                   126
# Germany                   97
#                         ...
# Georgia                    1
# New Line                   1
# Pakistan                   1
# United Arab Emirates       1
# Cameroon                   1
# Name: country, Length: 66, dtype: int64

# %%
counts.nlargest(3)
# Out:
# USA       3807
# UK         448
# France     154
# Name: country, dtype: int64

# %%
counts.nlargest(3).index
# Out:
# Index(['USA', 'UK', 'France'], dtype='object')

# %%
movies[movies.country.isin(counts.nlargest(3).index)].head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                     723       178
# 1  Color     Gore Verbinski                     302       169
# 2  Color         Sam Mendes                     602       148
# 3  Color  Christopher Nolan                     813       164
# 5  Color     Andrew Stanton                     462       132
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                        0                     855  Joel David Moore
# 1                      563                    1000     Orlando Bloom
# 2                        0                     161      Rory Kinnear
# 3                    22000                   23000    Christian Bale
# 5                      475                     530   Samantha Morton
#
#    actor_1_facebook_likes      gross                           genres  ...  \
# 0                    1000  760505847  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                   40000  309404152         Action|Adventure|Fantasy  ...
# 2                   11000  200074175        Action|Adventure|Thriller  ...
# 3                   27000  448130642                  Action|Thriller  ...
# 5                     640   73058679          Action|Adventure|Sci-Fi  ...
#
#   num_user_for_reviews language  country  content_rating     budget  \
# 0                 3054  English      USA           PG-13  237000000
# 1                 1238  English      USA           PG-13  300000000
# 2                  994  English       UK           PG-13  245000000
# 3                 2701  English      USA           PG-13  250000000
# 5                  738  English      USA           PG-13  263700000
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0        2009                    936        7.9          1.78
# 1        2007                   5000        7.1          2.35
# 2        2015                    393        6.8          2.35
# 3        2012                  23000        8.5          2.35
# 5        2012                    632        6.6          2.35
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 5                24000
#
# [5 rows x 28 columns]

# %% [markdown]
# ## handle missing values

# %%
ufo = pd.read_csv('ufo.csv')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.isna().sum()
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
ufo.isna().mean()
# Out:
# City               0.001371
# Colors Reported    0.842004
# Shape Reported     0.144948
# State              0.000000
# Time               0.000000
# dtype: float64

# %%
ufo.dropna(axis='columns').head()  #drop any column that contains NaN
# Out:
#   State             Time
# 0    NY   6/1/1930 22:00
# 1    NJ  6/30/1930 20:00
# 2    CO  2/15/1931 14:00
# 3    KS   6/1/1931 13:00
# 4    NY  4/18/1933 19:00

# %%
ufo.dropna(thresh=len(ufo)*0.9,axis='columns').head()    #drop any column that contains 90% NaN
# Out:
#                    City State             Time
# 0                Ithaca    NY   6/1/1930 22:00
# 1           Willingboro    NJ  6/30/1930 20:00
# 2               Holyoke    CO  2/15/1931 14:00
# 3               Abilene    KS   6/1/1931 13:00
# 4  New York Worlds Fair    NY  4/18/1933 19:00

# %% [markdown]
# ## split a string into multiple columns

# %%
df = pd.DataFrame({'name':['John Arthur Doe', 'Jane Ann Smith'],'location':['Los Angeles, CA', 'Washington, DC']})
df
# Out:
#               name         location
# 0  John Arthur Doe  Los Angeles, CA
# 1   Jane Ann Smith   Washington, DC

# %%
df.name.str.split(' ', expand=True)
# Out:
#       0       1      2
# 0  John  Arthur    Doe
# 1  Jane     Ann  Smith

# %%
df[['first','middle','last']] = df.name.str.split(' ', expand=True)
df
# Out:
#               name         location first  middle   last
# 0  John Arthur Doe  Los Angeles, CA  John  Arthur    Doe
# 1   Jane Ann Smith   Washington, DC  Jane     Ann  Smith

# %%
df[['City','State']]= df.location.str.split(',', expand=True)
df
# Out:
#               name         location first  middle   last         City State
# 0  John Arthur Doe  Los Angeles, CA  John  Arthur    Doe  Los Angeles    CA
# 1   Jane Ann Smith   Washington, DC  Jane     Ann  Smith   Washington    DC

# %% [markdown]
# ## expand a Series of lists into a DataFrame

# %%
df = pd.DataFrame({'col1':['a','b','c'], 'col2':[[10,40],[20,50],[30,60]]})
df
# Out:
#   col1      col2
# 0    a  [10, 40]
# 1    b  [20, 50]
# 2    c  [30, 60]

# %%
df_new = df.col2.apply(pd.Series)
df_new
# Out:
#     0   1
# 0  10  40
# 1  20  50
# 2  30  60

# %%
pd.concat([df,df_new],axis='columns')
# Out:
#   col1      col2   0   1
# 0    a  [10, 40]  10  40
# 1    b  [20, 50]  20  50
# 2    c  [30, 60]  30  60

# %% [markdown]
# ## aggregate by multiple functions

# %%
orders = pd.read_csv('restaurant-1-orders.csv')
orders.head(10)
# Out:
#    Order Number        Order Date               Item Name  Quantity  \
# 0         16118  03/08/2019 20:25           Plain Papadum         2
# 1         16118  03/08/2019 20:25        King Prawn Balti         1
# 2         16118  03/08/2019 20:25             Garlic Naan         1
# 3         16118  03/08/2019 20:25           Mushroom Rice         1
# 4         16118  03/08/2019 20:25     Paneer Tikka Masala         1
# 5         16118  03/08/2019 20:25           Mango Chutney         1
# 6         16117  03/08/2019 20:17              Plain Naan         1
# 7         16117  03/08/2019 20:17           Mushroom Rice         1
# 8         16117  03/08/2019 20:17  Tandoori Chicken (1/4)         1
# 9         16117  03/08/2019 20:17         Vindaloo - Lamb         1
#
#    Product Price  Total products
# 0           0.80               6
# 1          12.95               6
# 2           2.95               6
# 3           3.95               6
# 4           8.95               6
# 5           0.50               6
# 6           2.60               7
# 7           3.95               7
# 8           4.95               7
# 9           7.95               7

# %%
orders.columns
# Out:
# Index(['Order Number', 'Order Date', 'Item Name', 'Quantity', 'Product Price',
#        'Total products'],
#       dtype='object')

# %%
orders= orders.drop(columns=['Quantity'])
orders.head(10)
# Out:
#    Order Number        Order Date               Item Name  Product Price  \
# 0         16118  03/08/2019 20:25           Plain Papadum           0.80
# 1         16118  03/08/2019 20:25        King Prawn Balti          12.95
# 2         16118  03/08/2019 20:25             Garlic Naan           2.95
# 3         16118  03/08/2019 20:25           Mushroom Rice           3.95
# 4         16118  03/08/2019 20:25     Paneer Tikka Masala           8.95
# 5         16118  03/08/2019 20:25           Mango Chutney           0.50
# 6         16117  03/08/2019 20:17              Plain Naan           2.60
# 7         16117  03/08/2019 20:17           Mushroom Rice           3.95
# 8         16117  03/08/2019 20:17  Tandoori Chicken (1/4)           4.95
# 9         16117  03/08/2019 20:17         Vindaloo - Lamb           7.95
#
#    Total products
# 0               6
# 1               6
# 2               6
# 3               6
# 4               6
# 5               6
# 6               7
# 7               7
# 8               7
# 9               7

# %%
orders.columns = orders.columns.map(lambda x: x.replace(' ', '_'))
orders.columns
# Out:
# Index(['Order_Number', 'Order_Date', 'Item_Name', 'Product_Price',
#        'Total_products'],
#       dtype='object')

# %%
orders[orders.Order_Number==16118].Product_Price.sum()
# Out:
# 30.099999999999998

# %%
orders.groupby('Order_Number').Product_Price.sum()
# Out:
# Order_Number
# 630       3.95
# 647       3.95
# 648       3.95
# 651       3.95
# 764       3.95
#          ...
# 16114    13.90
# 16115    23.60
# 16116    33.75
# 16117    32.30
# 16118    30.10
# Name: Product_Price, Length: 13397, dtype: float64

# %%
orders.groupby('Order_Number').Product_Price.agg(['sum','count'])
# Out:
#                 sum  count
# Order_Number
# 630            3.95      1
# 647            3.95      1
# 648            3.95      1
# 651            3.95      1
# 764            3.95      1
# ...             ...    ...
# 16114         13.90      2
# 16115         23.60      7
# 16116         33.75      5
# 16117         32.30      7
# 16118         30.10      6
#
# [13397 rows x 2 columns]

# %% [markdown]
# ## combine the output of an aggregation with a DataFrame

# %%
len(orders.groupby('Order_Number').Product_Price.sum())
# Out:
# 13397

# %%
len(orders)
# Out:
# 74818

# %%
totalPrice = orders.groupby('Order_Number').Product_Price.transform('sum')
len(totalPrice)
# Out:
# 74818

# %%
orders['total_price']=totalPrice
orders.head(10)
# Out:
#    Order_Number        Order_Date               Item_Name  Product_Price  \
# 0         16118  03/08/2019 20:25           Plain Papadum           0.80
# 1         16118  03/08/2019 20:25        King Prawn Balti          12.95
# 2         16118  03/08/2019 20:25             Garlic Naan           2.95
# 3         16118  03/08/2019 20:25           Mushroom Rice           3.95
# 4         16118  03/08/2019 20:25     Paneer Tikka Masala           8.95
# 5         16118  03/08/2019 20:25           Mango Chutney           0.50
# 6         16117  03/08/2019 20:17              Plain Naan           2.60
# 7         16117  03/08/2019 20:17           Mushroom Rice           3.95
# 8         16117  03/08/2019 20:17  Tandoori Chicken (1/4)           4.95
# 9         16117  03/08/2019 20:17         Vindaloo - Lamb           7.95
#
#    Total_products  total_price
# 0               6         30.1
# 1               6         30.1
# 2               6         30.1
# 3               6         30.1
# 4               6         30.1
# 5               6         30.1
# 6               7         32.3
# 7               7         32.3
# 8               7         32.3
# 9               7         32.3

# %%
orders['percent_of_total']=orders.Product_Price/orders.total_price
orders.head(10)
# Out:
#    Order_Number        Order_Date               Item_Name  Product_Price  \
# 0         16118  03/08/2019 20:25           Plain Papadum           0.80
# 1         16118  03/08/2019 20:25        King Prawn Balti          12.95
# 2         16118  03/08/2019 20:25             Garlic Naan           2.95
# 3         16118  03/08/2019 20:25           Mushroom Rice           3.95
# 4         16118  03/08/2019 20:25     Paneer Tikka Masala           8.95
# 5         16118  03/08/2019 20:25           Mango Chutney           0.50
# 6         16117  03/08/2019 20:17              Plain Naan           2.60
# 7         16117  03/08/2019 20:17           Mushroom Rice           3.95
# 8         16117  03/08/2019 20:17  Tandoori Chicken (1/4)           4.95
# 9         16117  03/08/2019 20:17         Vindaloo - Lamb           7.95
#
#    Total_products  total_price  percent_of_total
# 0               6         30.1          0.026578
# 1               6         30.1          0.430233
# 2               6         30.1          0.098007
# 3               6         30.1          0.131229
# 4               6         30.1          0.297342
# 5               6         30.1          0.016611
# 6               7         32.3          0.080495
# 7               7         32.3          0.122291
# 8               7         32.3          0.153251
# 9               7         32.3          0.246130

# %% [markdown]
# ## select a slice of rows and columns

# %%
titanic = pd.read_csv('titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.describe().loc['min':'max']
# Out:
#      PassengerId  Survived  Pclass     Age  SibSp  Parch      Fare
# min          1.0       0.0     1.0   0.420    0.0    0.0    0.0000
# 25%        223.5       0.0     2.0  20.125    0.0    0.0    7.9104
# 50%        446.0       0.0     3.0  28.000    0.0    0.0   14.4542
# 75%        668.5       1.0     3.0  38.000    1.0    0.0   31.0000
# max        891.0       1.0     3.0  80.000    8.0    6.0  512.3292

# %%
titanic.describe().loc['min':'max','Pclass':'Parch']
# Out:
#      Pclass     Age  SibSp  Parch
# min     1.0   0.420    0.0    0.0
# 25%     2.0  20.125    0.0    0.0
# 50%     3.0  28.000    0.0    0.0
# 75%     3.0  38.000    1.0    0.0
# max     3.0  80.000    8.0    6.0

# %% [markdown]
# ## Reshape a multi-indexed Series

# %%
titanic.Survived.mean()
# Out:
# 0.3838383838383838

# %%
titanic.groupby('Sex').Survived.mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
titanic.groupby(['Sex','Pclass']).Survived.mean()
# Out:
# Sex     Pclass
# female  1         0.968085
#         2         0.921053
#         3         0.500000
# male    1         0.368852
#         2         0.157407
#         3         0.135447
# Name: Survived, dtype: float64

# %%
titanic.groupby(['Sex','Pclass']).Survived.mean().unstack()
# Out:
# Pclass         1         2         3
# Sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %% [markdown]
# ## create a pivot table

# %%
titanic.pivot_table(index='Sex',columns='Pclass',values='Survived',aggfunc='mean')
# Out:
# Pclass         1         2         3
# Sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
titanic.pivot_table(index='Sex',columns='Pclass',values='Survived',aggfunc='mean',margins=True)
# Out:
# Pclass         1         2         3       All
# Sex
# female  0.968085  0.921053  0.500000  0.742038
# male    0.368852  0.157407  0.135447  0.188908
# All     0.629630  0.472826  0.242363  0.383838

# %%
titanic.pivot_table(index='Sex',columns='Pclass',values='Survived',aggfunc='count',margins=True)
# Out:
# Pclass    1    2    3  All
# Sex
# female   94   76  144  314
# male    122  108  347  577
# All     216  184  491  891

# %% [markdown]
# ## convert continuous data into categorical data

# %%
titanic.Age.head(10)
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: Age, dtype: float64

# %%
pd.cut(titanic.Age,bins=[0,18,25,99],labels=['child','young','adult']).head(10)
# Out:
# 0    young
# 1    adult
# 2    adult
# 3    adult
# 4    adult
# 5      NaN
# 6    adult
# 7    child
# 8    adult
# 9    child
# Name: Age, dtype: category
# Categories (3, object): [child < young < adult]

# %% [markdown]
# ## change display options

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
pd.set_option('display.float_format','{:.2f}'.format)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male 22.00      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female 38.00      1
# 2                             Heikkinen, Miss. Laina  female 26.00      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.00      1
# 4                           Allen, Mr. William Henry    male 35.00      0
#
#    Parch            Ticket  Fare Cabin Embarked
# 0      0         A/5 21171  7.25   NaN        S
# 1      0          PC 17599 71.28   C85        C
# 2      0  STON/O2. 3101282  7.92   NaN        S
# 3      0            113803 53.10  C123        S
# 4      0            373450  8.05   NaN        S

# %%
pd.reset_option('display.float_format')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
#  ## profile a DataFrame

# %%
import pandas_profiling

# %%
pandas_profiling.ProfileReport(titanic)
# Out:
# /Users/FY/opt/anaconda3/lib/python3.7/site-packages/pandas_profiling/describe.py:392: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>12 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>891 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>8.1% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>83.7 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>96.1 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>6 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>4 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_Age"><code>Age</code></a> has 177 / 19.9% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_SibSp"><code>SibSp</code></a> has 608 / 68.2% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_Parch"><code>Parch</code></a> has 678 / 76.1% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_Ticket"><code>Ticket</code></a> has a high cardinality: 681 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Fare"><code>Fare</code></a> has 15 / 1.7% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_Cabin"><code>Cabin</code></a> has 687 / 77.1% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_Cabin"><code>Cabin</code></a> has a high cardinality: 148 distinct values  <span class="label label-warning">Warning</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_PassengerId">PassengerId<br/>
#             <small>Numeric</small>
#         </p>
#     </div><div
