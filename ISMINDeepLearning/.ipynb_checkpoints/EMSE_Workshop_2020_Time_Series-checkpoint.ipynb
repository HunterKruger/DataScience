# %%
# !pip install gdown
# !gdown https://drive.google.com/uc?id=16fNBGPSKQGOX0-5Cz0P8fLRlPMEU2HpS
# !unzip -qo 'TS_data.zip'
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.6/dist-packages (3.6.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from gdown) (1.12.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from gdown) (2.21.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from gdown) (4.28.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->gdown) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->gdown) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->gdown) (2019.11.28)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->gdown) (1.24.3)
# Downloading...
# From: https://drive.google.com/uc?id=16fNBGPSKQGOX0-5Cz0P8fLRlPMEU2HpS
# To: /content/TS_data.zip
# 100% 1.13M/1.13M [00:00<00:00, 5.26MB/s]

# %%
from os.path import join
import pandas
import numpy as np


bl = (None, {'Bill load (year 1) | (kWh)'})[1]
ts_label = 'Time stamp'
months = dict({'Jan': 0, 'Feb': 1, 'Mar': 2, 'Apr': 3, 'May': 4, 'Jun': 5,
               'Jul': 6, 'Aug': 7, 'Sep': 8, 'Oct': 9, 'Nov': 10, 'Dec': 11})
targets = ['System power generated | (kW)', 'Electricity load (year 1) | (kW)']


def time_stamp_numpy(ts):
    """ Time Stamp to 3 uint8 month, day, hour
    # Arguments
        :param ts: pandas series, time stamp
    # Returns
        :return nts: numpy array, month (0-11), day (0-30), hour (0-23), day of week (0-6)
    """
    nts = np.zeros((ts.shape[0], 4), dtype=np.uint8)
    for i, t in enumerate(ts):
        idx = t.find(' ')
        assert idx != -1, 'No space in "%s"' % ts_label
        assert t[:idx] in months, 'Unknown month: %s' % t[:idx]
        nts[i, 0], start = months[t[:idx]], idx + 1
        idx = t.find(', ', start)
        assert idx != -1, 'No comma followed by space in "%s"' % ts_label
        nts[i, 1], start = int(t[start:idx]) - 1, idx + 2
        nts[i, 2] = (int(t[start:start + 2]) % 12) + (12 if t.endswith(' pm') else 0)
        nts[i, 3] = i % 7
    return nts


def select_columns(df, targets, blc=bl):
    """ Select columns with variance and not blacklisted. Position of targets.
    # Arguments
        :param df: pandas dataframe, data
        :param targets: list of str, targets column's names
        :param blc: None / Set of str, column's names to skip (time stamp automatically added)
    # Returns
        :return: numpy array, values of selected columns
        :return t_pos: numpy array, targets positions
    """
    blc, res, t_pos = (set() if blc is None else blc) | {ts_label}, list(), -np.ones(len(targets), dtype=np.int64)
    for i, c in enumerate(df.columns):
        if c in blc:
            print('{:2d} Blacklisted %s'.format(i, c))
            continue
        uv = df[c].value_counts().to_dict()
        if len(uv) < 2:
            print('{:2d} No variance in {:s}'.format(i, c))
            continue
        th = max(list(uv.values())) / df.shape[0]
        if th > .95:
            print('{:2d} Single value > 95% of {:s}'.format(i, c))
            continue
        to_prt = '{:2d} {:<100s} {:<15s} {:.3f}'.format(i, c, str(df[c].dtype), th)
        if c in targets:
            t_idx = targets.index(c)
            t_pos[t_idx] = len(res)
            to_prt = '{:s} *Target {:d}*'.format(to_prt, t_idx)
        res.append(c)
        print(to_prt)
    return df[res].values, t_pos


def split_indexing(nbs, chunk, w=1, step=1, pred=0, pct_val=.2, pct_test=.2, seed=13120):
    """ Split data into train, valid and test. Return indexes for start of windows and index for statistics.
    # Arguments
        :param nbs: int, number of samples in full data set
        :param chunk: int, size of a data chunk
        :param w: int, time series window
        :param step: int, time series step
        :param pred: int, prediction look ahead
        :param pct_val: float, percentage of data used for validation
        :param pct_test: float, percentage if data used for testing
        :param seed: int, RNG seed
    # Returns
        :return ds: dict, dataset
            'train': numpy array, indexes of train data set
            'valid': numpy array, indexes of valid data set
            'test': numpy array, indexes of test data set
        :return idx_s, numpy array, indexes of train data set for statistics
    """
    np.random.seed(seed)
    p_max = nbs - w + 1 - pred
    nbc = p_max // chunk
    nb_val, nb_test = int(np.ceil(nbc * pct_val)), int(np.ceil(nbc * pct_test))
    perm = np.random.permutation(nbc)
    i_te, i_va, i_tr = set(perm[:nb_test]), set(perm[nb_test:nb_test + nb_val]), set(perm[nb_test + nb_val:])
    ds, idx_s = dict({'train': None, 'valid': None, 'test': None}), None
    for i in range(nbc):
        start = i * chunk
        if start >= p_max:
            break
        nxt_c = i + 1
        if i in i_te:
            ds_k, nxt_in = 'test', (nxt_c < nbc) and (nxt_c in i_te)
        elif i in i_va:
            ds_k, nxt_in = 'valid', (nxt_c < nbc) and (nxt_c in i_va)
        else:
            ds_k, nxt_in = 'train', (nxt_c < nbc) and (nxt_c in i_tr)
        end_range = min(p_max, nxt_c * chunk - (0 if nxt_in else w - 1))
        to_add = np.arange(start, end_range, step)
        ds[ds_k] = to_add if ds[ds_k] is None else np.concatenate((ds[ds_k], to_add))
        if ds == 'train':
            to_add = np.arange(start, end_range)
            idx_s = to_add if idx_s is None else np.concatenate((idx_s, to_add))
    return ds, idx_s


def load_select(data_file_name, targets, w, pred, chunk):
    """ * Load data file
        * Format time stamp
        * Select columns and find targets positions
        * split data set
    # Arguments
        :param data_file_name: str, data file name (with path)
        :param targets: list of str, targets names
        :param w: int, time series window
        :param pred: int, prediction look ahead
    # Returns
        :return nts: numpy array, time stamp
        :return data: numpy array, data selected and standardized
        :return idx: dict, data set indexes
        :return t_pos: numpy array, targets positions
        :return idx_s: dict, data set indexes of training samples
    """
    df = pandas.read_csv(data_file_name)
    nts = time_stamp_numpy(df[ts_label])
    data, t_pos = select_columns(df, targets)
    idx, idx_s = split_indexing(data.shape[0], chunk, w=w, pred=pred)
    return nts, data, idx, t_pos, idx_s

# %%
from os.path import join
from pickle import dump as pidump, load as piload
from csv import DictReader
from matplotlib import pyplot as plt
import numpy as np
import tensorflow as tf


model_path = join('.')


def get_stat(data, idx_s):
    """ Compute mean and standard deviation for each features in training set
    # Arguments
        :param data: numpy array, full data set
        :param idx_s: numpy arrat, training index for statistics
    # Returns
        :return stat: dict, statistics on training data
            'mean': numpy array, mean of each features
            'std': numpy array, standard deviation of each features
    """
    stat = dict({'mean': np.mean(data[idx_s], axis=1), 'std': np.std(data[idx_s], axis=1, ddof=1)})
    return stat


def apply_stat(data, stat):
    """ Standardize full data set
    # Arguments
        :param data: numpy array, full data set
        :param stat: dict, mean and std of training data
    # Returns
        :return: numpy array, standardized data
    """
    return (data - stat['mean']) / stat['std']


def load_select_standardize(data_file_name, targets, w, pred, chunk=12):
    """ * Load data file
        * Format time stamp
        * Select columns and find targets positions
        * split data set
        * Compute and apply statistics (standardization)
    # Arguments
        :param data_file_name: str, data file name (with path)
        :param targets: list of str, targets names
        :param w: int, time series window
        :param pred: int, prediction look ahead
        :param chunk: int, atomic size for splitting train, valid & test data
    # Returns
        :return nts: numpy array, time stamp
        :return data: numpy array, data selected and standardized
        :return idx: dict, data set indexes
        :return t_pos: numpy array, targets positions
    """
    nts, data, idx, t_pos, idx_s = load_select(data_file_name, targets, w, pred, chunk)
    stat = get_stat(data, idx_s)
    data = apply_stat(data, stat)
    return nts, data, idx, t_pos


def add_ts(data, nts, idx):
    """ Add time stamp data at the end of full data set
    # Arguments
        :param data: numpy array, data
        :param nts: numpy array, time stamp data
        :param idx: int, index of time stamp data to add
    # Returns
        :return: numpy, array, data augmented
    """
    id_m = np.eye(nts[:, idx].max() + 1)
    return np.concatenate((data, id_m[nts[:, idx]]), axis=-1)


def plot_log(filename, show=None):
    """ Plot  training / validation learning curve
    # Arguments
        :param filename: str, csv log file name
        :param show: None / str, show graph if none or save to show.png
    """
    keys, values, idx = list(), list(), None
    with open(filename, 'r') as f:
        reader = DictReader(f)
        for row in reader:
            if len(keys) == 0:
                for key, value in row.items():
                    keys.append(key)
                    values.append(float(value))
                idx = keys.index('epoch')
                continue
            for _, value in row.items():
                values.append(float(value))
        values = np.reshape(values, newshape=(-1, len(keys)))
        values[:, idx] += 1
    fig = plt.figure(figsize=(6, 9))
    fig.subplots_adjust(top=0.95, bottom=0.05, right=0.95)
    fig.add_subplot(211)
    for i, key in enumerate(keys):
        if key.find('loss') >= 0:   # and not key.find('val') >= 0:
            plt.plot(values[:, idx], values[:, i], label=key)
    plt.legend()
    plt.title('Training and validation loss')
    fig.add_subplot(212)
    for i, key in enumerate(keys):
        if key.find('mean') >= 0:
            plt.plot(values[:, idx], values[:, i], label=key)
    plt.legend()
    plt.title('Training and validation error')
    if show is not None:
        fig.savefig('%s.png' % show)
        plt.close(fig)
    else:
        plt.show()
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
def data_generator(data, idx, target, w, pred, noise=None, sn=None, batch=32):
    """ Generator for training / validating
    # Arguments
        :param data: numpy array, full data set
        :param idx: numpy array, index of samples
        :param target: int, target position in data set
        :param w: int, time series window
        :param pred: int, prediction look ahead
        :param noise: None / float, noise factor
        :param sn: None / int, noise separation position
        :param batch: int, batch
    # Yields
        :return bd: numpy array, data
        :return obj: numpy array, target
    """
    nbs, nbf, p_batch = idx.shape[0], data.shape[1] - 1, 0
    bd, obj, p_idx = np.zeros((batch, w, nbf), dtype=data.dtype), np.zeros(batch, dtype=data.dtype), nbs
    no_noise = np.zeros((batch, w, nbf - sn), dtype=data.dtype)
    while True:
        if p_idx == nbs:
            perm, p_idx = np.random.permutation(nbs), 0
        s = idx[perm[p_idx]]
        p_idx += 1
        bd[p_batch] = np.concatenate((data[s:s + w, :target], data[s:s + w, target + 1:]), axis=-1)
        obj[p_batch] = data[s + w - 1 + pred, target]
        p_batch += 1
        if p_batch == batch:
            if noise is not None:
                bd += np.concatenate((np.random.normal(scale=noise, size=(batch, w, sn)), no_noise), axis=-1)
            yield bd, obj
            p_batch = 0


def train_model(w, pred, name, data, idx, target, epoch=100, lr=1e-6, noise=None, sn=None, batch=16):
    """ Compile train and save log image for a model
    # Arguments
        :param w: int, window (time dimension)
        :param pred: int, prediction look ahead
        :param name: srt, name
        :param data: numpy array, full data set
        :param idx: dict, indexes of train / valid / test data set
        :param target: int, target position in data set
        :param epoch: int, epoch
        :param lr: float, learning rate
        :param noise: None / float, noise factor
        :param sn: None / int, noise separation position
        :param batch: int, batch (train & valid)
    """
    model = create_model(w, data.shape[1] - 1)
    model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=lr),
                  loss=tf.keras.losses.mse, metrics=['mape'])
    model.summary()
    g_tr = data_generator(data, idx['train'], target, w=w,
                          pred=pred, noise=noise, sn=sn, batch=batch)
    s_tr = int(np.ceil(idx['train'].shape[0] / batch))
    g_va = data_generator(data, idx['valid'], target, w=w,
                          pred=pred, noise=noise, sn=sn, batch=batch)
    s_va = int(np.ceil(idx['valid'].shape[0] / batch))
    fn = join(model_path, name)
    cb = list()
    cb.append(tf.keras.callbacks.CSVLogger('%s.log' % fn))
    cb.append(tf.keras.callbacks.ModelCheckpoint('%s.loss' % fn,
                                                 monitor='val_loss',
                                                 mode='min',
                                                 save_best_only=True))
    cb.append(tf.keras.callbacks.ModelCheckpoint('%s.last' % fn, save_freq=1))
    model.fit_generator(generator=g_tr, steps_per_epoch=s_tr,
                        validation_data=g_va, validation_steps=s_va,
                        epochs=epoch, verbose=1, callbacks=cb,
                        max_queue_size=10, use_multiprocessing=True)
    plot_log('%s.log' % fn, show='%s_log' % fn)


def full_predictions(m, data, ds, target, w, batch):
    """ Predict on data for model m
    # Arguments
        :param m: keras model
        :param data: numpy array, full data set
        :param ds: numpy array, indexes
        :param target: int, position of target in data set
        :param w: int, window (time dimension)
        :param batch: int, batch
    # Returns
        :return preds: numpy array, predictions
    """
    last, bd, p_b, preds = ds.shape[0] - 1, np.zeros((batch, w, data.shape[1] - 1)), 0, None
    for i, s in enumerate(ds):
        bd[p_b] = np.concatenate((data[s:s + w, :target], data[s:s + w, target + 1:]), axis=-1)
        p_b += 1
        if p_b == batch or i == last:
            p = m.predict_on_batch(bd[:p_b]).squeeze()
            preds = p if preds is None else np.concatenate((preds, p), axis=0)
            p_b = 0
    return preds


def pred_grap_nn(models, data, idx, target, w, pred, batch=128, t_idx='test', step=200):
    """ Predict and graph a list of models (on exact same data) and grand truth
    # Arguments
        :param models: list of str, file names of models to load and predict with
        :param data: numpy array, full data set (ready for predictions)
        :param idx: dict, indexes for train, valid & test data set
        :param target: int, psition of target in data set
        :param w: int, time series window (time dimension)
        :param pred: int, prediction look ahaed
        :param batch: int, batch
        :param t_idx: str,
    """
    predictions, grand_truth = list(), data[idx[t_idx] + w - 1 + pred, target]
    for name in models:
        print('Predict for %s' % name)
        fn = join(model_path, '%s.loss' % name)
        m = tf.keras.models.load_model(fn)
        predictions.append(full_predictions(m, data, idx[t_idx], target, w, batch))
    graph_comparison(predictions, data, idx, target, w, pred, t_idx=t_idx, step=step)


def graph_comparison(predictions, data, idx, target, w, pred, t_idx, step):
    """ Graph a list of models predictions (on exact same data) and grand truth
    # Arguments
        :param predictions: list of numpy array, predictions for all models to be graphed
        :param data: numpy array, full data set (ready for predictions)
        :param idx: dict, indexes for train, valid & test data set
        :param target: int, psition of target in data set
        :param w: int, time series window (time dimension)
        :param pred: int, prediction look ahaed
        :param batch: int, batch
        :param t_idx: str,
    """
    grand_truth, pos, nbg = data[idx[t_idx] + w - 1 + pred, target], 0, 0
    while pos < grand_truth.shape[0]:
        stop = pos + step
        if grand_truth.shape[0] - (stop + step) < step // 2:
            stop = grand_truth.shape[0]
        fig = plt.figure(figsize=(12, 6))
        for i in range(len(predictions)):
            plt.plot(predictions[i][pos:stop], '--', label='Model %d' % i)
        plt.plot(grand_truth[pos:stop], '-', label='Grand Truth')
        plt.legend()
        plt.title('Prediction comparison')
        fig.tight_layout()
        # fig.savefig(join(model_path, 'comparison_%s_%d.png' % (t_idx, nbg)))
        # plt.close(fig)
        plt.show()
        pos = stop
        nbg += 1

# %%
def create_model(w, c):
    """ Create a keras model
    # Arguments
        :param w: int, time dimension
        :param c: int, channel dimension
    # Returns
        :return: keras model
    """
    l_in = tf.keras.layers.Input(shape=(w, c,))
    lact = l_in

    lact = tf.keras.layers.ZeroPadding1D(1)(lact)
    lact = tf.keras.layers.Conv1D(16, 3, activation='relu')(lact)

    lact = tf.keras.layers.ZeroPadding1D(1)(lact)
    lact = tf.keras.layers.Conv1D(16, 3, activation='relu')(lact)

    lact = tf.keras.layers.GlobalAveragePooling1D()(lact)

    lact = tf.keras.layers.Dense(1, activation='linear')(lact)
    l_out = lact
    return tf.keras.models.Model(l_in, l_out)

# %%
data_file_name = join('resultsSolar.csv')
# data_file_name = join(resultsWind.csv')

# %%
w, pred, target = 6, 12, 1
nts, data, idx, t_pos = load_select_standardize(data_file_name, targets,
                                                w=w, pred=pred, chunk=72)
sep_noise = data.shape[1]
data = add_ts(data, nts, 0)     # add month
data = add_ts(data, nts, 2)     # add hour
data = add_ts(data, nts, 3)     # add day of week
name = '%sTar%d_w%dp%d' % ('Solar' if 'resultsSolar.csv' in data_file_name else 'Wind', target, w, pred)
# Out:
#  0 Blacklisted %s
#  1 Electricity from grid (year 1 hourly) | (kWh)                                                        float64         0.289
#  2 Electricity from system to load (year 1 hourly) | (kWh)                                              float64         0.528
#  3 System power generated | (kW)                                                                        float64         0.528 *Target 0*
#  4 No variance in TOU period for demand charges (year 1 hourly)
#  5 TOU period for energy charges (year 1 hourly)                                                        int64           0.689
#  6 Electricity load (year 1) | (kW)                                                                     float64         0.003 *Target 1*
#  7 Blacklisted %s
#  8 No variance in Demand charge with system (year 1 hourly) | ($)
#  9 No variance in Demand charge without system (year 1 hourly) | ($)
# 10 No variance in Electricity peak from grid per TOU period (year 1 hourly) | (kW)
# 11 Electricity peak from system to load (year 1 hourly) | (kW)                                          float64         0.528
# 12 Single value > 95% of Electricity sales/purchases with system (year 1 hourly) | ($)
# 13 Single value > 95% of Electricity sales/purchases without system (year 1 hourly) | ($)
# 14 Electricity to grid (year 1 hourly) | (kWh)                                                          float64         0.711
# 15 Electricity to/from grid (year 1 hourly) | (kWh)                                                     float64         0.003
# 16 Electricity to/from grid peak (year 1 hourly) | (kW)                                                 float64         0.003
# 17 Single value > 95% of Energy charge with system (year 1 hourly) | ($)
# 18 Single value > 95% of Energy charge without system (year 1 hourly) | ($)
# 19 No variance in Lifetime electricity load | (kW)
# 20 AC wiring loss | (kW)                                                                                float64         0.528
# 21 Absolute air mass                                                                                    float64         0.498
# 22 Array DC power | (kW)                                                                                float64         0.525
# 23 No variance in Array DC power loss due to snow | (kW)
# 24 Array POA beam radiation after shading and soiling | (kW)                                            float64         0.558
# 25 Array POA front-side beam radiation nominal | (kW)                                                   float64         0.558
# 26 Array POA front-side total radiation after cover | (kW)                                              float64         0.525
# 27 Array POA front-side total radiation after shading and soiling | (kW)                                float64         0.525
# 28 Array POA front-side total radiation after shading only | (kW)                                       float64         0.525
# 29 Array POA front-side total radiation nominal | (kW)                                                  float64         0.525
# 30 Array POA radiation total after cover | (kW)                                                         float64         0.525
# 31 No variance in Array POA rear-side total radiation after cover | (kW)
# 32 Inverter DC input voltage at MPPT 1 | (V)                                                            float64         0.525
# 33 Single value > 95% of Inverter clipping loss AC power limit | (kW)
# 34 No variance in Inverter clipping loss DC MPPT voltage limits | (kW)
# 35 Inverter efficiency | (%)                                                                            float64         0.528
# 36 Inverter night time loss | (kW)                                                                      float64         0.528
# 37 Inverter power consumption loss | (kW)                                                               float64         0.528
# 38 No variance in Inverter thermal derate loss | (kW)
# 39 Inverter total power loss | (kW)                                                                     float64         0.525
# 40 Irradiance DHI from weather file | (W/m2)                                                            int64           0.510
# 41 Irradiance DNI from weather file | (W/m2)                                                            int64           0.531
# 42 Irradiance GHI calculated | (W/m2)                                                                   float64         0.510
# 43 No variance in Irradiance GHI from weather file | (W/m2)
# 44 Subarray 1 Angle of incidence | (deg)                                                                float64         0.498
# 45 Subarray 1 Angle of incidence Modifier | (0-1)                                                       float64         0.525
# 46 No variance in Subarray 1 Axis rotation for 1 axis trackers | (deg)
# 47 No variance in Subarray 1 Axis rotation ideal for 1 axis trackers | (deg)
# 48 Subarray 1 Cell temperature | (C)                                                                    float64         0.525
# 49 No variance in Subarray 1 External shading and soiling beam irradiance factor | (frac)
# 50 Subarray 1 Module efficiency | (%)                                                                   float64         0.525
# 51 Subarray 1 Open circuit voltage | (V)                                                                float64         0.525
# 52 Subarray 1 Operating voltage | (V)                                                                   float64         0.525
# 53 Subarray 1 POA front beam irradiance after shading and soiling | (W/m2)                              float64         0.558
# 54 Subarray 1 POA front diffuse irradiance after shading and soiling | (W/m2)                           float64         0.525
# 55 Subarray 1 POA total front irradiance after module cover | (W/m2)                                    float64         0.525
# 56 Subarray 1 POA total front irradiance after shading and soiling | (W/m2)                             float64         0.525
# 57 Subarray 1 POA total front irradiance after shading only | (W/m2)                                    float64         0.525
# 58 Subarray 1 POA total front irradiance nominal | (W/m2)                                               float64         0.525
# 59 Subarray 1 POA total irradiance after module cover | (W/m2)                                          float64         0.525
# 60 No variance in Subarray 1 POA total rear irradiance after module cover | (W/m2)
# 61 No variance in Subarray 1 Partial external shading DC factor | (frac)
# 62 No variance in Subarray 1 Self-shading linear beam irradiance factor | (frac)
# 63 No variance in Subarray 1 Self-shading non-linear DC factor | (frac)
# 64 No variance in Subarray 1 Self-shading non-linear ground diffuse irradiance factor | (frac)
# 65 No variance in Subarray 1 Self-shading non-linear sky diffuse irradiance factor | (frac)
# 66 Subarray 1 Short circuit current | (A)                                                               float64         0.525
# 67 No variance in Subarray 1 Soiling beam irradiance factor | (frac)
# 68 Subarray 1 Surface azimuth | (deg)                                                                   int64           0.502
# 69 Subarray 1 Surface tilt | (deg)                                                                      int64           0.502
# 70 Sun altitude angle | (deg)                                                                           float64         0.498
# 71 Sun azimuth angle | (deg)                                                                            float64         0.498
# 72 Sun position time | (hour)                                                                           int64           0.498
# 73 Sun up over horizon | (0/1/2/3)                                                                      int64           0.502
# 74 Sun zenith angle | (deg)                                                                             float64         0.498
# 75 No variance in Transformer load loss | (kW)
# 76 No variance in Transformer no load loss | (kW)
# 77 No variance in Transformer total loss | (kW)
# 78 No variance in Transmission loss | (kW)
# 79 No variance in Weather file albedo
# 80 Weather file ambient temperature | (C)                                                               int64           0.039
# 81 No variance in Weather file snow depth | (cm)
# 82 Weather file wind speed | (m/s)                                                                      float64         0.065

# %%
model_name = '%s_NN' % name
train_model(w, pred, model_name, data, idx, t_pos[target],
            epoch=50, lr=1e-3, noise=1e-2, sn=sep_noise, batch=32)
models = [model_name,]
# pred_grap_nn(models, data, idx, t_pos[target], w, pred, t_idx='train')
# pred_grap_nn(models, data, idx, t_pos[target], w, pred, t_idx='valid')
pred_grap_nn(models, data, idx, t_pos[target], w, pred)
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 6, 92)]           0
# _________________________________________________________________
# zero_padding1d_2 (ZeroPaddin (None, 8, 92)             0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 6, 16)             4432
# _________________________________________________________________
# zero_padding1d_3 (ZeroPaddin (None, 8, 16)             0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 6, 16)             784
# _________________________________________________________________
# global_average_pooling1d_1 ( (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 5,233
# Trainable params: 5,233
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 152/155 [============================>.] - ETA: 0s - loss: 0.2434 - mean_absolute_percentage_error: 217.1721Epoch 1/50
# 155/155 [==============================] - 4s 29ms/step - loss: 0.2401 - mean_absolute_percentage_error: 214.4909 - val_loss: 0.0821 - val_mean_absolute_percentage_error: 100.6388
# Epoch 2/50
# 154/155 [============================>.] - ETA: 0s - loss: 0.0889 - mean_absolute_percentage_error: 171.1461Epoch 1/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0886 - mean_absolute_percentage_error: 170.4097 - val_loss: 0.0629 - val_mean_absolute_percentage_error: 85.1191
# Epoch 3/50
# 154/155 [============================>.] - ETA: 0s - loss: 0.0768 - mean_absolute_percentage_error: 189.2408Epoch 1/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0768 - mean_absolute_percentage_error: 190.8250 - val_loss: 0.0581 - val_mean_absolute_percentage_error: 85.2850
# Epoch 4/50
# 153/155 [============================>.] - ETA: 0s - loss: 0.0704 - mean_absolute_percentage_error: 224.2613Epoch 1/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0701 - mean_absolute_percentage_error: 222.1207 - val_loss: 0.0527 - val_mean_absolute_percentage_error: 82.0844
# Epoch 5/50
# 152/155 [============================>.] - ETA: 0s - loss: 0.0639 - mean_absolute_percentage_error: 132.4682Epoch 1/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0648 - mean_absolute_percentage_error: 132.2770 - val_loss: 0.0435 - val_mean_absolute_percentage_error: 70.4105
# Epoch 6/50
# 154/155 [============================>.] - ETA: 0s - loss: 0.0618 - mean_absolute_percentage_error: 167.0214Epoch 1/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0623 - mean_absolute_percentage_error: 166.3018 - val_loss: 0.0807 - val_mean_absolute_percentage_error: 97.1337
# Epoch 7/50
# 154/155 [============================>.] - ETA: 0s - loss: 0.0575 - mean_absolute_percentage_error: 196.0983Epoch 1/50
# 155/155 [==============================] - 4s 26ms/step - loss: 0.0576 - mean_absolute_percentage_error: 195.2669 - val_loss: 0.0461 - val_mean_absolute_percentage_error: 60.2139
# Epoch 8/50
# 152/155 [============================>.] - ETA: 0s - loss: 0.0559 - mean_absolute_percentage_error: 191.4709Epoch 1/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0559 - mean_absolute_percentage_error: 188.8585 - val_loss: 0.0435 - val_mean_absolute_percentage_error: 59.0606
# Epoch 9/50
# 154/155 [============================>.] - ETA: 0s - loss: 0.0526 - mean_absolute_percentage_error: 121.1841Epoch 1/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0525 - mean_absolute_percentage_error: 120.7504 - val_loss: 0.0994 - val_mean_absolute_percentage_error: 117.4111
# Epoch 10/50
# 154/155 [============================>.] - ETA: 0s - loss: 0.0523 - mean_absolute_percentage_error: 154.9439Epoch 1/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0522 - mean_absolute_percentage_error: 154.3308 - val_loss: 0.0429 - val_mean_absolute_percentage_error: 64.1806
# Epoch 11/50
# 154/155 [============================>.] - ETA: 0s - loss: 0.0498 - mean_absolute_percentage_error: 131.9925Epoch 1/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0499 - mean_absolute_percentage_error: 131.5006 - val_loss: 0.0413 - val_mean_absolute_percentage_error: 54.7839
# Epoch 12/50
# 154/155 [============================>.] - ETA: 0s - loss: 0.0490 - mean_absolute_percentage_error: 168.1153Epoch 1/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.0490 - mean_absolute_percentage_error: 167.2706 - val_loss: 0.0532 - val_mean_absolute_percentage_error: 70.7484
# Epoch 13/50
# 154/155 [============================>.] - ETA: 0s - loss: 0.0490 - mean_absolute_percentage_error: 175.6263Epoch 1/50
# 155/155 [==============================] - 4s 26ms/step - loss: 0.0493 - mean_absolute_percentage_error: 174.7535 - val_loss: 0.0429 - val_mean_absolute_percentage_error: 57.5185
# Epoch 14/50
# 154/155 [============================>.] - ETA: 0s - loss: 0.0469 - mean_absolute_percentage_error: 142.0989Epoch 1/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.0468 - mean_absolute_percentage_error: 141.3227 - val_loss: 0.0415 - val_mean_absolute_percentage_error: 62.7593
# Epoch 15/50
# 153/155 [============================>.] - ETA: 0s - loss: 0.0451 - mean_absolute_percentage_error: 161.5229Epoch 1/50
# 155/155 [==============================] - 4s 26ms/step - loss: 0.0449 - mean_absolute_percentage_error: 159.8643 - val_loss: 0.0398 - val_mean_absolute_percentage_error: 51.7783
# Epoch 16/50
# 152/155 [============================>.] - ETA: 0s - loss: 0.0464 - mean_absolute_percentage_error: 169.9638Epoch 1/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0461 - mean_absolute_percentage_error: 167.4891 - val_loss: 0.0437 - val_mean_absolute_percentage_error: 61.9631
# Epoch 17/50
# 154/155 [============================>.] - ETA: 0s - loss: 0.0451 - mean_absolute_percentage_error: 129.5753Epoch 1/50
# 155/155 [==============================] - 4s 27ms/step - loss: 0.0452 - mean_absolute_percentage_error: 129.2403 - val_loss: 0.0417 - val_mean_absolute_percentage_error: 57.2613
# Epoch 18/50
# 154/155 [============================>.] - ETA: 0s - loss: 0.0442 - mean_absolute_percentage_error: 124.2954Epoch 1/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0443 - mean_absolute_percentage_error: 124.0918 - val_loss: 0.0385 - val_mean_absolute_percentage_error: 50.2465
# Epoch 19/50
# 154/155 [============================>.] - ETA: 0s - loss: 0.0433 - mean_absolute_percentage_error: 132.2962Epoch 1/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.0433 - mean_absolute_percentage_error: 131.7453 - val_loss: 0.0459 - val_mean_absolute_percentage_error: 54.5873
# Epoch 20/50
# 153/155 [============================>.] - ETA: 0s - loss: 0.0430 - mean_absolute_percentage_error: 141.0291Epoch 1/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0428 - mean_absolute_percentage_error: 139.7919 - val_loss: 0.0386 - val_mean_absolute_percentage_error: 49.5921
# Epoch 21/50
# 152/155 [============================>.] - ETA: 0s - loss: 0.0418 - mean_absolute_percentage_error: 127.2099Epoch 1/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.0421 - mean_absolute_percentage_error: 126.1786 - val_loss: 0.0562 - val_mean_absolute_percentage_error: 59.2892
# Epoch 22/50
# 152/155 [============================>.] - ETA: 0s - loss: 0.0423 - mean_absolute_percentage_error: 108.7254Epoch 1/50
# 155/155 [==============================] - 4s 26ms/step - loss: 0.0420 - mean_absolute_percentage_error: 107.1347 - val_loss: 0.0414 - val_mean_absolute_percentage_error: 53.0646
# Epoch 23/50
# 153/155 [============================>.] - ETA: 0s - loss: 0.0413 - mean_absolute_percentage_error: 112.4839Epoch 1/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.0412 - mean_absolute_percentage_error: 111.4430 - val_loss: 0.0440 - val_mean_absolute_percentage_error: 61.8701
# Epoch 24/50
# 154/155 [============================>.] - ETA: 0s - loss: 0.0412 - mean_absolute_percentage_error: 115.7111Epoch 1/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0411 - mean_absolute_percentage_error: 115.0788 - val_loss: 0.0416 - val_mean_absolute_percentage_error: 53.3850
# Epoch 25/50
# 152/155 [============================>.] - ETA: 0s - loss: 0.0409 - mean_absolute_percentage_error: 112.9177Epoch 1/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0409 - mean_absolute_percentage_error: 111.6879 - val_loss: 0.0420 - val_mean_absolute_percentage_error: 60.7817
# Epoch 26/50
# 152/155 [============================>.] - ETA: 0s - loss: 0.0402 - mean_absolute_percentage_error: 120.1216Epoch 1/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0400 - mean_absolute_percentage_error: 118.8011 - val_loss: 0.0450 - val_mean_absolute_percentage_error: 53.1558
# Epoch 27/50
# 153/155 [============================>.] - ETA: 0s - loss: 0.0401 - mean_absolute_percentage_error: 127.9072Epoch 1/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0400 - mean_absolute_percentage_error: 126.5530 - val_loss: 0.0414 - val_mean_absolute_percentage_error: 51.1636
# Epoch 28/50
# 152/155 [============================>.] - ETA: 0s - loss: 0.0394 - mean_absolute_percentage_error: 77.9570Epoch 1/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0391 - mean_absolute_percentage_error: 77.2613 - val_loss: 0.0442 - val_mean_absolute_percentage_error: 47.1235
# Epoch 29/50
# 153/155 [============================>.] - ETA: 0s - loss: 0.0389 - mean_absolute_percentage_error: 140.4053Epoch 1/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0386 - mean_absolute_percentage_error: 139.1152 - val_loss: 0.0401 - val_mean_absolute_percentage_error: 48.7002
# Epoch 30/50
# 153/155 [============================>.] - ETA: 0s - loss: 0.0383 - mean_absolute_percentage_error: 136.9028Epoch 1/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0381 - mean_absolute_percentage_error: 135.9383 - val_loss: 0.0467 - val_mean_absolute_percentage_error: 56.1332
# Epoch 31/50
# 154/155 [============================>.] - ETA: 0s - loss: 0.0372 - mean_absolute_percentage_error: 110.8468Epoch 1/50
# 155/155 [==============================] - 4s 26ms/step - loss: 0.0371 - mean_absolute_percentage_error: 110.4570 - val_loss: 0.0385 - val_mean_absolute_percentage_error: 54.9250
# Epoch 32/50
# 153/155 [============================>.] - ETA: 0s - loss: 0.0388 - mean_absolute_percentage_error: 113.7585Epoch 1/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0386 - mean_absolute_percentage_error: 112.8172 - val_loss: 0.0385 - val_mean_absolute_percentage_error: 50.6603
# Epoch 33/50
# 152/155 [============================>.] - ETA: 0s - loss: 0.0364 - mean_absolute_percentage_error: 144.7763Epoch 1/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0362 - mean_absolute_percentage_error: 142.7540 - val_loss: 0.0397 - val_mean_absolute_percentage_error: 60.1022
# Epoch 34/50
# 154/155 [============================>.] - ETA: 0s - loss: 0.0372 - mean_absolute_percentage_error: 105.1538Epoch 1/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0375 - mean_absolute_percentage_error: 104.8017 - val_loss: 0.0614 - val_mean_absolute_percentage_error: 62.7669
# Epoch 35/50
# 154/155 [============================>.] - ETA: 0s - loss: 0.0370 - mean_absolute_percentage_error: 98.1683Epoch 1/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0371 - mean_absolute_percentage_error: 97.7789 - val_loss: 0.0372 - val_mean_absolute_percentage_error: 53.5613
# Epoch 36/50
# 153/155 [============================>.] - ETA: 0s - loss: 0.0355 - mean_absolute_percentage_error: 106.8448Epoch 1/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0356 - mean_absolute_percentage_error: 105.8619 - val_loss: 0.0406 - val_mean_absolute_percentage_error: 56.6754
# Epoch 37/50
# 153/155 [============================>.] - ETA: 0s - loss: 0.0359 - mean_absolute_percentage_error: 80.2997Epoch 1/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0357 - mean_absolute_percentage_error: 79.6310 - val_loss: 0.0451 - val_mean_absolute_percentage_error: 50.6450
# Epoch 38/50
# 153/155 [============================>.] - ETA: 0s - loss: 0.0345 - mean_absolute_percentage_error: 104.3775Epoch 1/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.0345 - mean_absolute_percentage_error: 103.8850 - val_loss: 0.0430 - val_mean_absolute_percentage_error: 56.1490
# Epoch 39/50
# 153/155 [============================>.] - ETA: 0s - loss: 0.0342 - mean_absolute_percentage_error: 131.2383Epoch 1/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.0341 - mean_absolute_percentage_error: 129.9093 - val_loss: 0.0361 - val_mean_absolute_percentage_error: 49.6316
# Epoch 40/50
# 153/155 [============================>.] - ETA: 0s - loss: 0.0354 - mean_absolute_percentage_error: 72.9148Epoch 1/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.0356 - mean_absolute_percentage_error: 72.5925 - val_loss: 0.0510 - val_mean_absolute_percentage_error: 55.1057
# Epoch 41/50
# 153/155 [============================>.] - ETA: 0s - loss: 0.0340 - mean_absolute_percentage_error: 99.5378 Epoch 1/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.0340 - mean_absolute_percentage_error: 98.8477 - val_loss: 0.0386 - val_mean_absolute_percentage_error: 53.3326
# Epoch 42/50
# 154/155 [============================>.] - ETA: 0s - loss: 0.0339 - mean_absolute_percentage_error: 104.2966Epoch 1/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0338 - mean_absolute_percentage_error: 104.3545 - val_loss: 0.0407 - val_mean_absolute_percentage_error: 53.4897
# Epoch 43/50
# 153/155 [============================>.] - ETA: 0s - loss: 0.0329 - mean_absolute_percentage_error: 129.1103Epoch 1/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.0328 - mean_absolute_percentage_error: 128.0103 - val_loss: 0.0394 - val_mean_absolute_percentage_error: 55.2370
# Epoch 44/50
# 153/155 [============================>.] - ETA: 0s - loss: 0.0331 - mean_absolute_percentage_error: 116.7390Epoch 1/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0332 - mean_absolute_percentage_error: 135.6918 - val_loss: 0.0408 - val_mean_absolute_percentage_error: 49.6213
# Epoch 45/50
# 153/155 [============================>.] - ETA: 0s - loss: 0.0320 - mean_absolute_percentage_error: 62.8995Epoch 1/50
# 155/155 [==============================] - 4s 24ms/step - loss: 0.0319 - mean_absolute_percentage_error: 62.6688 - val_loss: 0.0421 - val_mean_absolute_percentage_error: 56.4572
# Epoch 46/50
# 152/155 [============================>.] - ETA: 0s - loss: 0.0333 - mean_absolute_percentage_error: 91.3565Epoch 1/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0331 - mean_absolute_percentage_error: 90.2711 - val_loss: 0.0397 - val_mean_absolute_percentage_error: 54.1995
# Epoch 47/50
# 152/155 [============================>.] - ETA: 0s - loss: 0.0326 - mean_absolute_percentage_error: 124.1284Epoch 1/50
# 155/155 [==============================] - 5s 30ms/step - loss: 0.0325 - mean_absolute_percentage_error: 122.3784 - val_loss: 0.0397 - val_mean_absolute_percentage_error: 54.1424
# Epoch 48/50
# 153/155 [============================>.] - ETA: 0s - loss: 0.0323 - mean_absolute_percentage_error: 114.4708Epoch 1/50
# 155/155 [==============================] - 4s 27ms/step - loss: 0.0327 - mean_absolute_percentage_error: 128.4874 - val_loss: 0.0415 - val_mean_absolute_percentage_error: 65.8352
# Epoch 49/50
# 153/155 [============================>.] - ETA: 0s - loss: 0.0310 - mean_absolute_percentage_error: 73.4088Epoch 1/50
# 155/155 [==============================] - 4s 26ms/step - loss: 0.0307 - mean_absolute_percentage_error: 72.9048 - val_loss: 0.0389 - val_mean_absolute_percentage_error: 54.9528
# Epoch 50/50
# 152/155 [============================>.] - ETA: 0s - loss: 0.0326 - mean_absolute_percentage_error: 117.1190Epoch 1/50
# 155/155 [==============================] - 4s 25ms/step - loss: 0.0324 - mean_absolute_percentage_error: 115.5222 - val_loss: 0.0388 - val_mean_absolute_percentage_error: 56.8631
# Predict for SolarTar1_w6p12_NN

# %%
# !ls
# Out:
# resultsSolar.csv  SolarTar1_w6p1_GRU_Noise_small.last  SolarTar1_w6p1_SVR
# resultsWind.csv   SolarTar1_w6p1_GRU_Noise_small.log   TS_data.zip
# sample_data	  SolarTar1_w6p1_GRU_Noise_small.loss
